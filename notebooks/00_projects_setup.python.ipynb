# %% [markdown]
# # Data collection and project setup
#
# Summary of data collection steps followed in the Streptomyces pangenome project. This notebook describes all the projects and BGCFlow runs carried out in the study.

# %%
import pandas as pd
from pathlib import Path
import altair as alt
import yaml
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %% [markdown]
# ### File Configuration

# %%
with open("config.yaml", "r") as f:
    notebook_configuration = yaml.safe_load(f)
notebook_configuration
# Out:
# {'bgcflow_dir': '/datadrive/bgcflow'}

# %% [markdown]
# # 1. Setup qc project with all genomes from NCBI
#
# 2938 genome accessions were collected from the NCBI RefSeq database on the 30-06-2023 for genomes belonging to Streptomycetaceae family

# %%
tables_dir = Path("assets/tables/")
ncbi_accn_table = tables_dir / "streptomycetaceae_refseq_30062023.tsv"

# %%
df_ncbi_accn = pd.read_csv(ncbi_accn_table, sep="\t", index_col=2)
df_ncbi_accn.head()
# Out:
#                                        GenBank Assembly ID (Accession.version)  \
# RefSeq Assembly ID (Accession.version)
# GCF_000009765.2                                                GCA_000009765.2
# GCF_000010605.1                                                GCA_000010605.1
# GCF_000091305.1                                                GCA_000091305.1
# GCF_000092385.1                                                GCA_000092385.1
# GCF_000147815.2                                                GCA_000147815.3
#
#                                         GenBank release ID  \
# RefSeq Assembly ID (Accession.version)
# GCF_000009765.2                                    3140618
# GCF_000010605.1                                      11408
# GCF_000091305.1                                     111938
# GCF_000092385.1                                     113018
# GCF_000147815.2                                     300768
#
#                                         RefSeq release ID   Unnamed: 4
# RefSeq Assembly ID (Accession.version)
# GCF_000009765.2                                    3192468         NaN
# GCF_000010605.1                                      32088         NaN
# GCF_000091305.1                                     163818         NaN
# GCF_000092385.1                                     354548         NaN
# GCF_000147815.2                                     301138         NaN

# %%
samples_columns = ["source","organism","genus","species","strain","closest_placement_reference"]
df_samples_strepto_ncbi_all = pd.DataFrame(index=df_ncbi_accn.index, columns=samples_columns)
df_samples_strepto_ncbi_all.index.name = "genome_id"
df_samples_strepto_ncbi_all.source = "ncbi"
df_samples_strepto_ncbi_all.head()
# Out:
#                 source organism genus species strain  \
# genome_id
# GCF_000009765.2   ncbi      NaN   NaN     NaN    NaN
# GCF_000010605.1   ncbi      NaN   NaN     NaN    NaN
# GCF_000091305.1   ncbi      NaN   NaN     NaN    NaN
# GCF_000092385.1   ncbi      NaN   NaN     NaN    NaN
# GCF_000147815.2   ncbi      NaN   NaN     NaN    NaN
#
#                 closest_placement_reference
# genome_id
# GCF_000009765.2                         NaN
# GCF_000010605.1                         NaN
# GCF_000091305.1                         NaN
# GCF_000092385.1                         NaN
# GCF_000147815.2                         NaN

# %%
# df_samples_strepto_ncbi_all.to_csv(tables_dir / "df_samples_strepto_ncbi_all.csv")

# %% [markdown]
# ### Setup the config project using BGCFlow wrapper
#
# Follow the guide to set up a project called "qc_strepto_ncbi" with about df_samples tables and project config with the following rules
#
# ```
# cd bgcflow_dir
# bgcflow init --project qc_strepto_ncbi
# cp .examples/_genome_project_example/prokka-db.csv config/qc_strepto_ncbi/
# ```

# %%
# Write samples.csv table to config directory of qc_strepto_ncbi project
bgcflow_dir = Path(notebook_configuration["bgcflow_dir"])
project_name_1 = "qc_strepto_ncbi"

config_dir_1 = bgcflow_dir / f"config/{project_name_1}"
# df_samples.to_csv(config_dir / "samples.csv")

# %% [markdown]
# ## Update project_config
#
# Update the file `config/qc_strepto_ncbi/project_config.yaml` to allow seqfu rule on.
#
# Note that the latest release 214 of GTDB was used here with version 2.3.0 updated in the `workflow/envs/gtdbtk.yaml` file.
#
# ```
# name: qc_strepto_ncbi
# pep_version: 2.1.0
# description: '2938 genome accessions were collected from the NCBI RefSeq database
# on the 30-06-2023 for genomes belonging to Streptomycetaceae family'
# sample_table: samples.csv
# prokka-db: 'prokka-db.csv'
# rules:
#   seqfu: true
#
# #### CUSTOM RULE CONFIGURATION ####
# rule_parameters:  install_gtdbtk:
#     release: "214"
#     release_version: "214"
# ```

# %% [markdown]
# ## Evaluate the results of the above first BGCFlow run
#
# Key tables generated:
#
# 1. df_ncbi_meta : NCBI metadata
# 2. df_gtdb_meta: GTDB metadata for genomes available in the release 214
# 3. df_seqfu_meta: Genome assembly statistics using seqfu rule

# %%
processed_dir_1 = bgcflow_dir / "data" / "processed" / project_name_1

# Read output tables from the processed directory
ncbi_meta_table_1 = processed_dir_1 / "tables"/ "df_ncbi_meta.csv"
df_ncbi_meta_1 = pd.read_csv(ncbi_meta_table_1, index_col= 0)

gtdb_meta_table_1 = processed_dir_1 / "tables"/ "df_gtdb_meta.csv"
df_gtdb_meta_1 = pd.read_csv(gtdb_meta_table_1, index_col= 0)

seqfu_meta_table_1 = processed_dir_1 / "tables"/ "df_seqfu_stats.csv"
df_seqfu_meta_1 = pd.read_csv(seqfu_meta_table_1, index_col= 0)

# %% [markdown]
# ### Genomes not found in GTDB
#
# A particular version of GTDB might not contain all of the genomes from NCBI. Some genomes dont have information on the CheckM.

# %%
df_gtdb_meta_1.detail.value_counts()
# Out:
# detail
# Genome found                                                  2542
# Genome not found                                               390
# Genome not found - no taxonomic assignment in release R214       6
# Name: count, dtype: int64

# %%
df_gtdb_meta_1.Genus.value_counts()
# Out:
# Genus
# g__Streptomyces           2468
# g__                        364
# g__Kitasatospora            70
# g__Streptacidiphilus        15
# g__Embleya                   4
# g__Streptomyces_D            3
# g__Streptomyces_A            3
# g__Yinghuangia               2
# g__Amycolatopsis             1
# g__Streptacidiphilus_A       1
# g__Williamsia                1
# g__Quadrisphaera             1
# g__Streptomyces_G            1
# g__Kribbella                 1
# g__Allostreptomyces          1
# g__SCUT-3                    1
# g__Moraxella_A               1
# Name: count, dtype: int64

# %%
df_gtdb_absent = df_gtdb_meta_1[df_gtdb_meta_1.detail != "Genome found"]
gtdb_absent_table = processed_dir_1 / "tables"/ "df_gtdb_absent.csv"

# df_gtdb_absent.to_csv(gtdb_absent_table)

# %% [markdown]
# # 2. Set up GTDBtk run for the remaining genomes
#
# In this second BGCFlow run, a project is setup to run GTDBTk and CheckM to assess the taxonomy and assembly quality for genomes not found in R214 version of GTDB server along with the genomes from the NBC strain collection.
#
# 1. df_gtdb_absent : 396 NCBI genomes that were not found in the GTDB server.
# 2. df_samples_NBC_1023: List of 1023 actinomycetes from the NBC collection. Note that some of these are redundant with NCBI database and thus are removed.

# %% [markdown]
# ### Setup the config project using BGCFlow wrapper
#
# Follow the guide to set up a project called "qc_gtdbtk" with samples tables and project config with the following rules
#
# ```
# cd bgcflow_dir
# bgcflow init --project qc_gtdbtk
# cp .examples/_genome_project_example/prokka-db.csv config/qc_gtdbtk/
# ```

# %% [markdown]
# ## Update project_config
#
# Update the file `config/qc_strepto_ncbi/project_config.yaml` to allow seqfu rule on.
#
# Note that the latest release 214 of GTDB was used here with version 2.3.0 updated in the `workflow/envs/gtdbtk.yaml` file.
#
# ```
# name: qc_gtdbtk
# pep_version: 2.1.0
# description: 'Project to assess taxonomy and assembly quality of 396 NCBI + 902 NBC genomes.'
# sample_table: samples.csv
# prokka-db: 'prokka-db.csv'
# rules:
#   seqfu: true
#   checkm: false
#   gtdbtk: false
#
# #### CUSTOM RULE CONFIGURATION ####
# rule_p  install_gtdbtk:
#     release: "214"lease: "214"
#     release_version: "214"
# "```

# %%
# Write samples.csv table to config directory of qc_strepto_ncbi project
project_name_2 = "qc_gtdbtk"

config_dir_2 = bgcflow_dir / f"config/{project_name_2}"

# %%
# Read NBC data file (manually created for custom genomes). Follow documentation of BGCFlow for custom samples.
samples_NBC_table = config_dir_2 / "samples_NBC_1023.csv"
df_samples_NBC_1023 = pd.read_csv(samples_NBC_table, index_col=0)

# %% [markdown]
# ### Remove redundant genomes
#
# As some of th NBC genomes were already part of NCBI dataset on 30 June 2023, we removed them from the custom project and kept the NCBI versions. All these genomes were part of the BioProject: PRJNA747871.

# %%
redundant_strain_list = df_ncbi_meta_1[df_ncbi_meta_1.BioProject == "PRJNA747871"].strain.tolist()
print("The number of genomes that were removed from NBC dataset:", len(redundant_strain_list))
df_samples_NBC_902 = df_samples_NBC_1023.drop(redundant_strain_list)
# Out:
# The number of genomes that were removed from NBC dataset: 121

# %%
df_ncbi_meta_1.assembly_level.value_counts()
# Out:
# assembly_level
# Contig             1495
# Scaffold            936
# Complete Genome     453
# Chromosome           54
# Name: count, dtype: int64

# %% [markdown]
# ### Add fasta files for custom genomes
#
# The fasta files for all 902 genomes were manuaully added to the directory `data/raw/fasta/`.

# %% [markdown]
# ### Combine the GTDBTk project
#
# Samples table for the GTDBTk project is created with the 902 NBC genomes and 396 NCBI genomes without taxonomic/ assembly quality informatio

# %%
df_samples_gtdb_absent = df_samples_strepto_ncbi_all.loc[df_gtdb_absent.index,:] 

df_samples_gtdbtk = pd.concat([df_samples_NBC_902, df_samples_gtdb_absent])

# %%
# # Save the samples tables
# df_samples_gtdb_absent.to_csv(config_dir_2/ "samples_NCBI_gtdb_absent.csv")
# df_samples_NBC_902.to_csv(config_dir_2/ "samples_NBC_902.csv")
# df_samples_gtdbtk.to_csv(config_dir_2/ "samples.csv")

# %% [markdown]
# ## Evaluate the results of the above first BGCFlow run on gtdbtk
#
# Key tables generated:
#
# 1. gtdbtk.bac120.summary.tsv: GTDB-Tk based taxonomic identification with version 214
# 2. df_seqfu_stats: Genome assembly statistics using seqfu rule
# 3. df_checkm_stats: Genome assembly statistics using CheckM rule

# %%
processed_dir_2 = bgcflow_dir / "data" / "processed" / project_name_2

# Read output tables from the processed directory
ncbi_meta_table_2 = processed_dir_2 / "tables"/ "df_ncbi_meta.csv"
df_ncbi_meta_2 = pd.read_csv(ncbi_meta_table_2, index_col= 0)

gtdb_meta_table_2 = processed_dir_2 / "tables"/ "df_gtdb_meta.csv"
df_gtdb_meta_2 = pd.read_csv(gtdb_meta_table_2, index_col= 0)

seqfu_meta_table_2 = processed_dir_2 / "tables"/ "df_seqfu_stats.csv"
df_seqfu_meta_2 = pd.read_csv(seqfu_meta_table_2, index_col= 0)

check_meta_table_2 = processed_dir_2 / "tables"/ "df_checkm_stats.csv"
df_checkm_meta_2 = pd.read_csv(check_meta_table_2, index_col= 0)

gtdbtk_meta_table_2 = processed_dir_2 / "tables"/ "gtdbtk.bac120.summary.tsv"
df_gtdbtk_meta_2 = pd.read_csv(gtdbtk_meta_table_2, index_col= 0, sep="\t")

# %%
df_checkm_meta_2.sort_values("Completeness")
# Out:
#                  Completeness  Contamination        GC    GC std  Genome size  \
# genome_id
# NBC_01635            0.000000       0.000000  0.710487  0.030986      9003324
# GCF_013302945.1      8.620690       0.000000  0.713604  0.028444      1335511
# GCF_023669525.1     82.445141      60.736677  0.716594  0.010725     14173392
# GCF_025398775.1     90.665236       0.000000  0.724229  0.000000      7687527
# GCF_016432765.1     91.244635       0.085837  0.721482  0.042171      8364241
# ...                       ...            ...       ...       ...          ...
# GCF_007677905.1    100.000000      12.970457  0.720057  0.026564      8192675
# NBC_01801          100.000000       3.479466  0.710333  0.000000     11975494
# GCF_001636945.2    100.000000       1.394850  0.710039  0.013189     10017507
# GCF_001279805.1    100.000000       1.754386  0.734291  0.024386      9490701
# NBC_01796          100.000000       1.315789  0.705956  0.000000      8562983
#
#                  # ambiguous bases  # scaffolds  # contigs  Longest scaffold  \
# genome_id
# NBC_01635                        0            2          2           8982372
# GCF_013302945.1              10254          332        443             61290
# GCF_023669525.1                  0          182        182            404509
# GCF_025398775.1             222271            1       1020           7687527
# GCF_016432765.1                  0            5          5           8111009
# ...                            ...          ...        ...               ...
# GCF_007677905.1                920         1578       1591            757584
# NBC_01801                        0            1          1          11975494
# GCF_001636945.2                  0            3          3           9260562
# GCF_001279805.1                  0          528        528            212011
# NBC_01796                        0            1          1           8562983
#
#                  Longest contig  N50 (scaffolds)  N50 (contigs)  \
# genome_id
# NBC_01635               8982372          8982372        8982372
# GCF_013302945.1           56941            11311           8543
# GCF_023669525.1          404509           109952         109952
# GCF_025398775.1           70481          7687527          11827
# GCF_016432765.1         8111009          8111009        8111009
# ...                         ...              ...            ...
# GCF_007677905.1          442105           224336         195329
# NBC_01801              11975494         11975494       11975494
# GCF_001636945.2         9260562          9260562        9260562
# GCF_001279805.1          212011            46679          46679
# NBC_01796               8562983          8562983        8562983
#
#                  Mean scaffold length  Mean contig length  Coding density  \
# genome_id
# NBC_01635                4.501662e+06        4.501662e+06        0.897961
# GCF_013302945.1          4.022623e+03        2.991551e+03        0.829939
# GCF_023669525.1          7.787578e+04        7.787578e+04        0.890316
# GCF_025398775.1          7.687527e+06        7.318878e+03        0.817609
# GCF_016432765.1          1.672848e+06        1.672848e+06        0.834695
# ...                               ...                 ...             ...
# GCF_007677905.1          5.191809e+03        5.148809e+03        0.873614
# NBC_01801                1.197549e+07        1.197549e+07        0.890382
# GCF_001636945.2          3.339169e+06        3.339169e+06        0.865050
# GCF_001279805.1          1.797481e+04        1.797481e+04        0.867294
# NBC_01796                8.562983e+06        8.562983e+06        0.889024
#
#                  Translation table  # predicted genes
# genome_id
# NBC_01635                        4               3814
# GCF_013302945.1                 11               1446
# GCF_023669525.1                 11              13000
# GCF_025398775.1                 11               6999
# GCF_016432765.1                 11               7920
# ...                            ...                ...
# GCF_007677905.1                 11               8485
# NBC_01801                       11              10987
# GCF_001636945.2                 11               8924
# GCF_001279805.1                 11               8328
# NBC_01796                       11               7518
#
# [1298 rows x 17 columns]

# %% [markdown]
# # 3. Rerun checkM on NBC_01635
#
# Above assessment showed that CheckM registered the completeness value of 0 for the genome NBC_01635. Thus, we reran CheckM only on this genome.
#
# NOTE: It seemed that translation table 4 was being used instead of 11. We manually edited the rule of checkM to use custom Prokka based gene annotation as input instead of fasta nucleotide file.

# %% [markdown]
# ### Setup the config project using BGCFlow wrapper
#
# Follow the guide to set up a project called "checkm_rerun" with samples tables and project config with the following rules
#
# ```
# cd bgcflow_dir
# bgcflow init --project checkm_rerun
# cp .examples/_genome_project_example/prokka-db.csv config/checkm_rerun/
# ```

# %% [markdown]
# ## Update project_config
#
# Update the file `config/checkm_rerun/project_config.yaml` to allow seqfu rule on.
#
# ```
# name: qc_strepto_ncbi
# pep_version: 2.1.0
# description: 'CheckM rerun for the genome NBC_01635'
# sample_table: samples.csv
# prokka-db: 'prokka-db.csv'
# rules:
#   checkm: True
# ```
#
# NOTE: We manually edited the rule of checkM to use custom Prokka based gene annotation as input instead of fasta nucleotide file. Thus the results will not be generated automatically.*

# %%
# Write samples.csv table to config directory of qc_strepto_ncbi project
project_name_3 = "checkm_rerun"

config_dir_3 = bgcflow_dir / f"config/{project_name_3}"

samples_columns = ["source","organism","genus","species","strain","closest_placement_reference"]
df_samples_checkm_rerun = pd.DataFrame(index=["NBC_01635"], columns=samples_columns)
df_samples_checkm_rerun.index.name = "genome_id"
df_samples_checkm_rerun.loc["NBC_01635", :] = df_samples_gtdbtk.loc["NBC_01635", :]
df_samples_checkm_rerun.to_csv(config_dir_3 / "samples.csv")

# %%
processed_dir_3 = bgcflow_dir / "data" / "processed" / project_name_3

check_meta_table_3 = processed_dir_3 / "tables"/ "df_checkm_stats.csv"
df_checkm_meta_3 = pd.read_csv(check_meta_table_3, index_col= 0)

# %% [markdown]
# ### Update the checkM table to include the updated results

# %%
df_checkm_meta_2.loc["NBC_01635", :] = df_checkm_meta_3.loc["NBC_01635", :]
# df_checkm_meta_2.to_csv(processed_dir_2 / "tables" / "df_checkm_stats_curated.csv")

# %% [markdown]
# ### Assess gtdbtk data and extract Streptomyces genus

# %%
# Remove genomes without classification
df_gtdb_meta = df_gtdb_meta_1.copy()
df_gtdbtk_meta_2 = df_gtdbtk_meta_2[df_gtdbtk_meta_2.classification != "Unclassified Bacteria"]

tax_mapping = {"d" : "Domain",
              "p" : "Phylum",
              "c" : "Class",
              "o" : "Order",
              "f" : "Family",
              "g" : "Genus",
              "s" : "Organism"}

for index in df_gtdbtk_meta_2.index:
    tax = [i for i in df_gtdbtk_meta_2.loc[index, "classification"].split(";")]
    for level in tax:
        key = level.split("__")[0]
        if key == "g":
            genus = level.split("__")[-1]
        if level == "s__":
            level = f"s__{genus} sp."
        df_gtdb_meta.loc[index, tax_mapping[key]] = level
    df_gtdb_meta.loc[index, "gtdb_release"] = "R214"
    df_gtdb_meta.loc[index, "detail"] = "found using gtdbtk"
df_gtdb_meta.Species = [i.split()[-1] for i in df_gtdb_meta.Organism]

# %%
df_gtdbtk_meta_curated_2 = df_gtdb_meta.loc[df_seqfu_meta_2.index,:]
# df_gtdbtk_meta_curated_2.to_csv(processed_dir_2/ "tables"/ "df_gtdbtk_meta_curated.csv")
# df_gtdb_meta.to_csv(processed_dir_1/ "tables"/ "df_gtdb_meta_curated.csv")

# %% [markdown]
# ### Assess checkM, SeqFu data and define quality filters

# %%
df_seqfu_meta = df_seqfu_meta_1.combine_first(df_seqfu_meta_2)

# %%
# Manually load NBC genomes assembly_level status
df_nbc_assembly_level = pd.read_csv(config_dir_2/ "df_nbc_assembly_level.csv", index_col=0)

# %%
df = pd.DataFrame(index=df_gtdb_meta.index, columns=["genome_id", "genus", "source", "species", "quality", "completeness", "contamination", "N50", "contigs", "genome_len"])
df["genome_id"] = df.index


for genome_id in df.index:
    # Define genus
    if genome_id in df_gtdb_meta.index:
        genus = df_gtdb_meta.loc[genome_id, "Genus"].split("__")[1]
        species = df_gtdb_meta.loc[genome_id, "Species"]
        
        df.loc[genome_id, "species"] = species
        df.loc[genome_id, "genus"] = genus
    else:
        print(genome_id, "not found in df_gtdb_meta!")
        
    # Define quality levels
    if genome_id in df_ncbi_meta_1.index:
        df.loc[genome_id, "source"] = "NCBI"
        assembly_level = df_ncbi_meta_1.loc[genome_id, "assembly_level"]
    else:
        df.loc[genome_id, "source"] = "NBC"
        if genome_id in df_nbc_assembly_level.index:
            assembly_level = df_nbc_assembly_level.loc[genome_id, "assembly_level"]
        else:
            assembly_level = "Complete Genome"

            
    # Define checkM metrics of completeness and contamination
    if genome_id in df_checkm_meta_2.index:
        completeness = df_checkm_meta_2.loc[genome_id, "Completeness"]
        contamination = df_checkm_meta_2.loc[genome_id, "Contamination"]
    else:
        completeness = df_gtdb_meta.loc[genome_id, "checkm_completeness"]
        contamination = df_gtdb_meta.loc[genome_id, "checkm_contamination"]

    df.loc[genome_id, 'completeness'] = completeness
    df.loc[genome_id, 'contamination'] = contamination

    # Define seqfu metrics of N50 and Contigs
    df.loc[genome_id, 'N50'] = df_seqfu_meta.loc[genome_id, "N50"]
    df.loc[genome_id, 'contigs'] = df_seqfu_meta.loc[genome_id, "Count"]
    df.loc[genome_id, 'genome_len'] = df_seqfu_meta.loc[genome_id, "Total"]
    df.loc[genome_id, 'gc'] = df_seqfu_meta.loc[genome_id, "gc"]

    # Define the quality of genomes
    if contamination > 5 or completeness < 90:
        df.loc[genome_id, "quality"] = "LQ"
        print(genome_id, "removed.", "Contamination:", contamination, "Completeness:",completeness)
    else:
        if assembly_level in ["Complete Genome", "Chromosome"]:
            df.loc[genome_id, "quality"] = "HQ"
        else:
            contigs = df_seqfu_meta.loc[genome_id, "Count"]
            N50 = df_seqfu_meta.loc[genome_id, "N50"]
            if contigs <= 100 and  N50 >= 100000:
                df.loc[genome_id, "quality"] = "MQ"
            else:
                print(genome_id, "removed.", "Contigs:", contigs, "N50:", N50)
                df.loc[genome_id, "quality"] = "LQ"

df_stats = df.copy()
# Out:
# GCF_000154885.1 removed. Contamination: 2.39 Completeness: 84.47
# GCF_000154925.1 removed. Contamination: 1.4 Completeness: 75.3
# GCF_000179195.1 removed. Contigs: 254 N50: 59002
# GCF_000179215.1 removed. Contigs: 1275 N50: 9224
# GCF_000225525.1 removed. Contigs: 525 N50: 31811
# GCF_000239075.1 removed. Contigs: 284 N50: 59300
# GCF_000242715.1 removed. Contigs: 244 N50: 113361
# GCF_000258595.1 removed. Contigs: 243 N50: 33216
# GCF_000259895.1 removed. Contigs: 729 N50: 20147
# GCF_000262345.1 removed. Contigs: 385 N50: 30588
# GCF_000280905.1 removed. Contigs: 109 N50: 121115
# GCF_000317595.1 removed. Contigs: 687 N50: 26361
# GCF_000331005.1 removed. Contigs: 692 N50: 27448
# GCF_000332625.1 removed. Contigs: 379 N50: 56781
# GCF_000342125.1 removed. Contigs: 266 N50: 47194
# GCF_000342345.1 removed. Contigs: 171 N50: 79071
# GCF_000367365.1 removed. Contigs: 202 N50: 124739
# GCF_000372745.1 removed. Contigs: 191 N50: 180969
# GCF_000373585.1 removed. Contigs: 120 N50: 169228
# GCF_000376565.1 removed. Contigs: 178 N50: 135550
# GCF_000380165.1 removed. Contigs: 112 N50: 136252
# GCF_000383615.1 removed. Contigs: 116 N50: 235831
# GCF_000403765.2 removed. Contigs: 242 N50: 75627
# GCF_000411315.1 removed. Contamination: 16.81 Completeness: 100.0
# GCF_000414115.1 removed. Contigs: 568 N50: 32382
# GCF_000415505.1 removed. Contigs: 1726 N50: 23632
# GCF_000498935.1 removed. Contigs: 1508 N50: 6247
# GCF_000504065.1 removed. Contigs: 244 N50: 67182
# GCF_000518045.1 removed. Contigs: 367 N50: 46890
# GCF_000590515.1 removed. Contigs: 290 N50: 95768
# GCF_000696595.1 removed. Contigs: 602 N50: 27217
# GCF_000698945.1 removed. Contamination: 0.57 Completeness: 89.7
# GCF_000700005.2 removed. Contigs: 152 N50: 358441
# GCF_000707965.1 removed. Contigs: 375 N50: 419227
# GCF_000710465.2 removed. Contigs: 846 N50: 24761
# GCF_000715745.1 removed. Contigs: 130 N50: 130234
# GCF_000715845.1 removed. Contigs: 223 N50: 86123
# GCF_000716215.1 removed. Contigs: 141 N50: 141587
# GCF_000716335.1 removed. Contigs: 114 N50: 230062
# GCF_000716435.1 removed. Contigs: 211 N50: 356030
# GCF_000716445.1 removed. Contigs: 259 N50: 125151
# GCF_000716455.1 removed. Contigs: 138 N50: 167875
# GCF_000716515.1 removed. Contigs: 140 N50: 199375
# GCF_000716525.1 removed. Contigs: 334 N50: 166038
# GCF_000716535.1 removed. Contigs: 232 N50: 194920
# GCF_000716545.1 removed. Contigs: 227 N50: 89226
# GCF_000716605.1 removed. Contigs: 242 N50: 208591
# GCF_000716615.1 removed. Contigs: 408 N50: 110620
# GCF_000716625.1 removed. Contigs: 155 N50: 142934
# GCF_000716675.1 removed. Contigs: 171 N50: 134286
# GCF_000716685.1 removed. Contigs: 181 N50: 171873
# GCF_000716745.1 removed. Contigs: 134 N50: 178926
# GCF_000716805.1 removed. Contigs: 323 N50: 150519
# GCF_000716845.1 removed. Contigs: 144 N50: 178168
# GCF_000716875.1 removed. Contigs: 250 N50: 73927
# GCF_000716885.1 removed. Contigs: 505 N50: 127928
# GCF_000716935.1 removed. Contigs: 263 N50: 264758
# GCF_000716965.1 removed. Contigs: 298 N50: 97127
# GCF_000717025.1 removed. Contigs: 106 N50: 332139
# GCF_000717055.1 removed. Contigs: 181 N50: 287302
# GCF_000717105.1 removed. Contigs: 178 N50: 201367
# GCF_000717185.1 removed. Contigs: 340 N50: 69365
# GCF_000717285.1 removed. Contigs: 129 N50: 199295
# GCF_000717345.1 removed. Contigs: 131 N50: 181980
# GCF_000717375.1 removed. Contigs: 135 N50: 186085
# GCF_000717595.1 removed. Contigs: 170 N50: 235906
# GCF_000717635.1 removed. Contigs: 201 N50: 89962
# GCF_000717645.1 removed. Contigs: 105 N50: 251927
# GCF_000717655.1 removed. Contigs: 151 N50: 193099
# GCF_000717715.1 removed. Contigs: 186 N50: 140273
# GCF_000717725.1 removed. Contigs: 139 N50: 107132
# GCF_000717795.1 removed. Contigs: 166 N50: 457602
# GCF_000717805.1 removed. Contigs: 205 N50: 111583
# GCF_000717815.1 removed. Contigs: 190 N50: 105458
# GCF_000717845.1 removed. Contigs: 170 N50: 148200
# GCF_000717875.1 removed. Contigs: 120 N50: 198010
# GCF_000717895.1 removed. Contigs: 221 N50: 185581
# GCF_000717925.1 removed. Contigs: 193 N50: 176453
# GCF_000717945.1 removed. Contigs: 198 N50: 122830
# GCF_000717965.1 removed. Contigs: 126 N50: 178044
# GCF_000717995.1 removed. Contigs: 282 N50: 176436
# GCF_000718025.1 removed. Contigs: 138 N50: 241189
# GCF_000718095.1 removed. Contigs: 117 N50: 275119
# GCF_000718135.1 removed. Contigs: 127 N50: 353815
# GCF_000718155.1 removed. Contigs: 357 N50: 164157
# GCF_000718165.1 removed. Contigs: 263 N50: 163841
# GCF_000718175.1 removed. Contamination: 6.94 Completeness: 99.84
# GCF_000718235.1 removed. Contigs: 142 N50: 246180
# GCF_000718295.1 removed. Contigs: 318 N50: 140407
# GCF_000718305.1 removed. Contigs: 108 N50: 381655
# GCF_000718315.1 removed. Contigs: 244 N50: 135213
# GCF_000718375.1 removed. Contigs: 211 N50: 203395
# GCF_000718525.1 removed. Contigs: 239 N50: 69828
# GCF_000718595.1 removed. Contigs: 126 N50: 232053
# GCF_000718615.1 removed. Contigs: 107 N50: 213680
# GCF_000718625.1 removed. Contigs: 217 N50: 193158
# GCF_000718635.1 removed. Contigs: 118 N50: 268175
# GCF_000718675.1 removed. Contigs: 138 N50: 269003
# GCF_000718705.1 removed. Contigs: 119 N50: 196648
# GCF_000718715.1 removed. Contigs: 619 N50: 61988
# GCF_000718755.1 removed. Contigs: 191 N50: 112113
# GCF_000718775.1 removed. Contigs: 322 N50: 65939
# GCF_000718815.1 removed. Contigs: 187 N50: 134513
# GCF_000718835.1 removed. Contigs: 132 N50: 196548
# GCF_000718855.1 removed. Contigs: 140 N50: 185916
# GCF_000718865.1 removed. Contigs: 111 N50: 179168
# GCF_000718895.1 removed. Contigs: 137 N50: 176334
# GCF_000718915.1 removed. Contigs: 104 N50: 181139
# GCF_000718935.1 removed. Contigs: 173 N50: 179028
# GCF_000718945.1 removed. Contigs: 666 N50: 96156
# GCF_000718955.1 removed. Contigs: 142 N50: 157367
# GCF_000718985.1 removed. Contigs: 195 N50: 155964
# GCF_000719015.1 removed. Contigs: 432 N50: 158037
# GCF_000719035.1 removed. Contigs: 228 N50: 213728
# GCF_000719095.1 removed. Contigs: 144 N50: 245740
# GCF_000719175.1 removed. Contigs: 279 N50: 121651
# GCF_000719185.1 removed. Contigs: 247 N50: 100266
# GCF_000719255.1 removed. Contigs: 155 N50: 246757
# GCF_000719285.1 removed. Contigs: 183 N50: 232223
# GCF_000719335.1 removed. Contigs: 255 N50: 115936
# GCF_000719345.1 removed. Contigs: 673 N50: 132442
# GCF_000719365.1 removed. Contigs: 294 N50: 70195
# GCF_000719425.1 removed. Contigs: 163 N50: 144165
# GCF_000719435.1 removed. Contigs: 165 N50: 117486
# GCF_000719475.1 removed. Contigs: 237 N50: 83861
# GCF_000719495.1 removed. Contigs: 240 N50: 90004
# GCF_000719505.1 removed. Contigs: 180 N50: 353313
# GCF_000719555.1 removed. Contigs: 187 N50: 102805
# GCF_000719575.1 removed. Contigs: 215 N50: 180744
# GCF_000719605.1 removed. Contigs: 124 N50: 205734
# GCF_000719625.1 removed. Contigs: 146 N50: 149483
# GCF_000719655.1 removed. Contigs: 146 N50: 125728
# GCF_000719665.1 removed. Contigs: 183 N50: 209060
# GCF_000719705.1 removed. Contigs: 253 N50: 124046
# GCF_000719735.1 removed. Contigs: 154 N50: 161668
# GCF_000719745.1 removed. Contigs: 188 N50: 97062
# GCF_000719775.1 removed. Contigs: 117 N50: 335080
# GCF_000719785.1 removed. Contigs: 169 N50: 170501
# GCF_000719815.1 removed. Contigs: 229 N50: 120967
# GCF_000719855.1 removed. Contigs: 131 N50: 150827
# GCF_000719865.1 removed. Contigs: 126 N50: 218508
# GCF_000719925.1 removed. Contigs: 104 N50: 230623
# GCF_000719955.1 removed. Contigs: 115 N50: 160497
# GCF_000720055.1 removed. Contigs: 101 N50: 280718
# GCF_000720065.1 removed. Contigs: 568 N50: 202225
# GCF_000720115.1 removed. Contigs: 156 N50: 187787
# GCF_000720135.1 removed. Contigs: 235 N50: 270940
# GCF_000720145.1 removed. Contigs: 208 N50: 168927
# GCF_000720175.1 removed. Contigs: 228 N50: 98196
# GCF_000720185.1 removed. Contigs: 162 N50: 132248
# GCF_000720215.1 removed. Contigs: 155 N50: 298601
# GCF_000720235.1 removed. Contigs: 113 N50: 207938
# GCF_000720255.1 removed. Contigs: 265 N50: 183856
# GCF_000720295.1 removed. Contigs: 1030 N50: 222074
# GCF_000720325.1 removed. Contigs: 362 N50: 132760
# GCF_000720455.1 removed. Contigs: 133 N50: 284155
# GCF_000720475.1 removed. Contigs: 223 N50: 156070
# GCF_000720485.1 removed. Contigs: 147 N50: 211967
# GCF_000720505.1 removed. Contigs: 1504 N50: 15145
# GCF_000720565.1 removed. Contigs: 129 N50: 198600
# GCF_000720595.1 removed. Contamination: 2.31 Completeness: 87.9
# GCF_000720605.1 removed. Contigs: 129 N50: 196306
# GCF_000720635.1 removed. Contigs: 233 N50: 91579
# GCF_000720645.1 removed. Contigs: 252 N50: 98420
# GCF_000720675.1 removed. Contigs: 130 N50: 184506
# GCF_000720685.1 removed. Contigs: 119 N50: 180248
# GCF_000720715.1 removed. Contigs: 214 N50: 100330
# GCF_000720725.1 removed. Contigs: 292 N50: 78793
# GCF_000720755.1 removed. Contigs: 236 N50: 154951
# GCF_000720765.1 removed. Contigs: 163 N50: 508937
# GCF_000720795.1 removed. Contigs: 129 N50: 167750
# GCF_000720835.1 removed. Contigs: 163 N50: 185677
# GCF_000720875.1 removed. Contigs: 271 N50: 114732
# GCF_000721035.1 removed. Contigs: 174 N50: 95686
# GCF_000721045.1 removed. Contigs: 183 N50: 169596
# GCF_000721105.1 removed. Contigs: 182 N50: 192242
# GCF_000721155.1 removed. Contigs: 158 N50: 174329
# GCF_000721175.1 removed. Contigs: 167 N50: 178406
# GCF_000721185.1 removed. Contigs: 139 N50: 201589
# GCF_000721235.1 removed. Contigs: 188 N50: 199385
# GCF_000721255.1 removed. Contigs: 270 N50: 129169
# GCF_000721265.1 removed. Contigs: 168 N50: 454671
# GCF_000721305.1 removed. Contigs: 257 N50: 108097
# GCF_000721335.1 removed. Contigs: 167 N50: 163325
# GCF_000721345.1 removed. Contigs: 368 N50: 66847
# GCF_000721365.1 removed. Contigs: 215 N50: 134293
# GCF_000721415.1 removed. Contigs: 152 N50: 107760
# GCF_000721435.1 removed. Contigs: 199 N50: 133692
# GCF_000721445.1 removed. Contigs: 167 N50: 323733
# GCF_000721455.1 removed. Contigs: 130 N50: 159310
# GCF_000721495.1 removed. Contigs: 250 N50: 107840
# GCF_000721515.1 removed. Contigs: 231 N50: 122082
# GCF_000721525.1 removed. Contigs: 260 N50: 160615
# GCF_000721535.1 removed. Contigs: 369 N50: 159554
# GCF_000721605.1 removed. Contigs: 179 N50: 296163
# GCF_000721665.1 removed. Contigs: 176 N50: 213895
# GCF_000721715.1 removed. Contigs: 171 N50: 257525
# GCF_000721935.1 removed. Contamination: 0.35 Completeness: 87.27
# GCF_000721945.1 removed. Contigs: 814 N50: 22397
# GCF_000721955.1 removed. Contigs: 106 N50: 169644
# GCF_000722185.1 removed. Contigs: 327 N50: 229674
# GCF_000725465.1 removed. Contigs: 225 N50: 232827
# GCF_000725475.1 removed. Contigs: 218 N50: 256603
# GCF_000725495.1 removed. Contigs: 131 N50: 317517
# GCF_000725545.1 removed. Contigs: 129 N50: 254413
# GCF_000725555.1 removed. Contigs: 127 N50: 254674
# GCF_000725565.1 removed. Contigs: 125 N50: 220172
# GCF_000725575.1 removed. Contigs: 124 N50: 184782
# GCF_000725625.1 removed. Contigs: 167 N50: 141967
# GCF_000725635.1 removed. Contigs: 123 N50: 243609
# GCF_000725645.1 removed. Contigs: 132 N50: 294936
# GCF_000725655.1 removed. Contigs: 939 N50: 225947
# GCF_000725715.1 removed. Contigs: 599 N50: 20270
# GCF_000725725.1 removed. Contigs: 147 N50: 246997
# GCF_000725745.1 removed. Contigs: 205 N50: 136678
# GCF_000725785.1 removed. Contigs: 141 N50: 285929
# GCF_000725805.1 removed. Contigs: 163 N50: 253485
# GCF_000725885.1 removed. Contigs: 104 N50: 245715
# GCF_000787755.1 removed. Contigs: 155 N50: 132365
# GCF_000787775.1 removed. Contigs: 139 N50: 125279
# GCF_000787815.1 removed. Contigs: 184 N50: 96689
# GCF_000787835.1 removed. Contigs: 107 N50: 144573
# GCF_000787855.1 removed. Contigs: 153 N50: 107739
# GCF_000797385.1 removed. Contigs: 295 N50: 68754
# GCF_000816485.1 removed. Contigs: 164 N50: 139282
# GCF_000955965.1 removed. Contigs: 233 N50: 220724
# GCF_000956015.1 removed. Contigs: 437 N50: 31162
# GCF_000958545.1 removed. Contigs: 115 N50: 386995
# GCF_000961885.1 removed. Contigs: 411 N50: 74283
# GCF_000966955.1 removed. Contigs: 1416 N50: 14614
# GCF_000966965.1 removed. Contigs: 434 N50: 45490
# GCF_000966975.1 removed. Contigs: 1874 N50: 8690
# GCF_000968685.2 removed. Contigs: 282 N50: 135927
# GCF_000972385.1 removed. Contigs: 856 N50: 91294
# GCF_000972395.1 removed. Contigs: 242 N50: 88608
# GCF_000972435.1 removed. Contigs: 548 N50: 28950
# GCF_000974985.2 removed. Contigs: 199 N50: 108867
# GCF_000978515.1 removed. Contigs: 989 N50: 14661
# GCF_000980885.2 removed. Contigs: 235 N50: 123175
# GCF_000981895.1 removed. Contigs: 648 N50: 23420
# GCF_000988945.1 removed. Contigs: 1056 N50: 16369
# GCF_001005085.2 removed. Contigs: 214 N50: 126586
# GCF_001005405.1 removed. Contigs: 1091 N50: 15103
# GCF_001008135.1 removed. Contigs: 909 N50: 19141
# GCF_001008345.1 removed. Contigs: 172 N50: 101336
# GCF_001014595.1 removed. Contigs: 122 N50: 120255
# GCF_001044185.1 removed. Contigs: 117 N50: 199354
# GCF_001044425.1 removed. Contigs: 163 N50: 95271
# GCF_001047315.1 removed. Contigs: 502 N50: 60064
# GCF_001047325.1 removed. Contigs: 329 N50: 120470
# GCF_001083795.1 removed. Contigs: 691 N50: 19693
# GCF_001182915.1 removed. Contigs: 1461 N50: 11328
# GCF_001188955.3 removed. Contigs: 107 N50: 228236
# GCF_001190165.1 removed. Contigs: 208 N50: 82381
# GCF_001270025.1 removed. Contigs: 350 N50: 54489
# GCF_001270485.1 removed. Contigs: 307 N50: 99945
# GCF_001270495.1 removed. Contigs: 277 N50: 113641
# GCF_001270505.1 removed. Contigs: 244 N50: 106664
# GCF_001270515.1 removed. Contigs: 424 N50: 62708
# GCF_001270565.1 removed. Contigs: 403 N50: 82152
# GCF_001270575.1 removed. Contigs: 304 N50: 75047
# GCF_001270585.1 removed. Contigs: 382 N50: 56727
# GCF_001270635.1 removed. Contigs: 343 N50: 81290
# GCF_001270675.1 removed. Contigs: 102 N50: 157297
# GCF_001279005.1 removed. Contigs: 288 N50: 158158
# GCF_001279015.1 removed. Contigs: 288 N50: 81262
# GCF_001279025.1 removed. Contigs: 310 N50: 89378
# GCF_001279065.1 removed. Contigs: 299 N50: 83235
# GCF_001279075.1 removed. Contigs: 336 N50: 79020
# GCF_001279095.1 removed. Contigs: 305 N50: 88462
# GCF_001279105.1 removed. Contigs: 365 N50: 70517
# GCF_001279345.1 removed. Contigs: 436 N50: 55924
# GCF_001279355.1 removed. Contigs: 291 N50: 92178
# GCF_001279365.1 removed. Contigs: 327 N50: 68059
# GCF_001279375.1 removed. Contigs: 367 N50: 80348
# GCF_001279425.1 removed. Contigs: 170 N50: 132393
# GCF_001279445.1 removed. Contigs: 218 N50: 94059
# GCF_001279455.1 removed. Contigs: 315 N50: 108182
# GCF_001279485.1 removed. Contigs: 315 N50: 78963
# GCF_001279495.1 removed. Contigs: 283 N50: 74316
# GCF_001279545.1 removed. Contigs: 264 N50: 164402
# GCF_001279605.1 removed. Contigs: 210 N50: 166107
# GCF_001279615.1 removed. Contigs: 226 N50: 140163
# GCF_001279625.1 removed. Contigs: 324 N50: 98566
# GCF_001279655.1 removed. Contigs: 259 N50: 91629
# GCF_001279685.1 removed. Contigs: 260 N50: 94956
# GCF_001279695.1 removed. Contigs: 362 N50: 90898
# GCF_001279725.1 removed. Contigs: 479 N50: 78201
# GCF_001279735.1 removed. Contigs: 190 N50: 111333
# GCF_001279765.1 removed. Contigs: 255 N50: 114603
# GCF_001279775.1 removed. Contigs: 294 N50: 98746
# GCF_001279805.1 removed. Contigs: 528 N50: 46679
# GCF_001279815.1 removed. Contigs: 202 N50: 130425
# GCF_001279845.1 removed. Contigs: 254 N50: 97762
# GCF_001279855.1 removed. Contigs: 232 N50: 103181
# GCF_001279885.1 removed. Contigs: 220 N50: 130619
# GCF_001279905.1 removed. Contigs: 260 N50: 104603
# GCF_001279925.1 removed. Contigs: 207 N50: 102927
# GCF_001279935.1 removed. Contigs: 258 N50: 86405
# GCF_001279965.1 removed. Contigs: 216 N50: 119376
# GCF_001279985.1 removed. Contigs: 425 N50: 126856
# GCF_001280005.1 removed. Contigs: 500 N50: 57397
# GCF_001280015.1 removed. Contigs: 273 N50: 150870
# GCF_001280045.1 removed. Contigs: 374 N50: 101769
# GCF_001280065.1 removed. Contigs: 184 N50: 209231
# GCF_001280095.1 removed. Contigs: 287 N50: 69817
# GCF_001280125.1 removed. Contigs: 287 N50: 69469
# GCF_001280885.1 removed. Contigs: 243 N50: 135294
# GCF_001282115.1 removed. Contigs: 692 N50: 22932
# GCF_001294335.1 removed. Contigs: 217 N50: 166063
# GCF_001294345.1 removed. Contigs: 238 N50: 322709
# GCF_001418125.1 removed. Contigs: 754 N50: 16752
# GCF_001418135.1 removed. Contigs: 707 N50: 17878
# GCF_001418165.1 removed. Contigs: 796 N50: 15219
# GCF_001418175.1 removed. Contigs: 811 N50: 16823
# GCF_001418325.1 removed. Contigs: 703 N50: 24134
# GCF_001418335.1 removed. Contigs: 561 N50: 29280
# GCF_001418385.1 removed. Contigs: 578 N50: 23290
# GCF_001418395.1 removed. Contigs: 1027 N50: 9198
# GCF_001418415.1 removed. Contigs: 783 N50: 18113
# GCF_001418465.1 removed. Contigs: 727 N50: 24820
# GCF_001418475.1 removed. Contigs: 1008 N50: 16332
# GCF_001418495.1 removed. Contigs: 743 N50: 11466
# GCF_001418505.1 removed. Contigs: 644 N50: 18934
# GCF_001418545.1 removed. Contigs: 940 N50: 11479
# GCF_001418565.1 removed. Contigs: 859 N50: 19214
# GCF_001418575.1 removed. Contigs: 802 N50: 17726
# GCF_001418585.1 removed. Contigs: 963 N50: 18170
# GCF_001418625.1 removed. Contigs: 767 N50: 18132
# GCF_001418645.1 removed. Contigs: 1411 N50: 10145
# GCF_001418655.1 removed. Contigs: 702 N50: 29593
# GCF_001419685.1 removed. Contigs: 631 N50: 25418
# GCF_001419695.1 removed. Contigs: 1058 N50: 8888
# GCF_001419705.1 removed. Contigs: 860 N50: 12922
# GCF_001419745.1 removed. Contigs: 732 N50: 20506
# GCF_001419765.1 removed. Contigs: 1055 N50: 15874
# GCF_001419795.1 removed. Contigs: 1456 N50: 10150
# GCF_001469455.2 removed. Contigs: 183 N50: 137942
# GCF_001484625.1 removed. Contigs: 225 N50: 61612
# GCF_001485105.1 removed. Contigs: 278 N50: 82196
# GCF_001485125.1 removed. Contigs: 147 N50: 193185
# GCF_001493375.1 removed. Contigs: 143 N50: 569072
# GCF_001507395.1 removed. Contigs: 315 N50: 87969
# GCF_001507435.1 removed. Contigs: 312 N50: 153060
# GCF_001509475.1 removed. Contigs: 424 N50: 73780
# GCF_001509485.1 removed. Contigs: 297 N50: 62597
# GCF_001509505.1 removed. Contigs: 282 N50: 104904
# GCF_001509565.1 removed. Contigs: 287 N50: 67140
# GCF_001509775.1 removed. Contigs: 439 N50: 140380
# GCF_001509785.1 removed. Contigs: 144 N50: 128237
# GCF_001509795.1 removed. Contigs: 137 N50: 134487
# GCF_001513965.1 removed. Contigs: 129 N50: 265228
# GCF_001514305.1 removed. Contigs: 152 N50: 214515
# GCF_001517125.1 removed. Contamination: 6.08 Completeness: 87.98
# GCF_001541145.1 removed. Contigs: 307 N50: 88399
# GCF_001550215.1 removed. Contigs: 1383 N50: 13060
# GCF_001550225.1 removed. Contigs: 1798 N50: 10646
# GCF_001550235.1 removed. Contamination: 6.48 Completeness: 95.29
# GCF_001550245.1 removed. Contigs: 1650 N50: 10930
# GCF_001550295.1 removed. Contigs: 1330 N50: 12509
# GCF_001550315.1 removed. Contigs: 1875 N50: 8672
# GCF_001550325.1 removed. Contigs: 1080 N50: 17738
# GCF_001550375.1 removed. Contigs: 931 N50: 21182
# GCF_001553435.1 removed. Contigs: 133 N50: 179494
# GCF_001553455.1 removed. Contigs: 680 N50: 28354
# GCF_001553475.1 removed. Contigs: 539 N50: 40212
# GCF_001570645.1 removed. Contigs: 217 N50: 97148
# GCF_001572115.1 removed. Contigs: 1464 N50: 12557
# GCF_001579685.1 removed. Contigs: 1173 N50: 9944
# GCF_001595515.1 removed. Contigs: 264 N50: 58042
# GCF_001642695.1 removed. Contigs: 197 N50: 4553814
# GCF_001642995.1 removed. Contigs: 207 N50: 86423
# GCF_001646665.1 removed. Contigs: 413 N50: 225771
# GCF_001652895.1 removed. Contigs: 259 N50: 62902
# GCF_001653115.1 removed. Contigs: 139 N50: 143984
# GCF_001653515.1 removed. Contamination: 3.24 Completeness: 87.67
# GCF_001661615.1 removed. Contigs: 902 N50: 14733
# GCF_001700505.1 removed. Contigs: 410 N50: 35885
# GCF_001700515.1 removed. Contigs: 732 N50: 21630
# GCF_001704635.1 removed. Contigs: 276 N50: 72375
# GCF_001705785.1 removed. Contigs: 125 N50: 317920
# GCF_001723055.1 removed. Contigs: 608 N50: 24673
# GCF_001723065.1 removed. Contigs: 1885 N50: 7160
# GCF_001723075.1 removed. Contigs: 1229 N50: 11948
# GCF_001723115.1 removed. Contigs: 1108 N50: 13772
# GCF_001746285.1 removed. Contigs: 236 N50: 67345
# GCF_001746305.1 removed. Contigs: 131 N50: 147588
# GCF_001746315.1 removed. Contigs: 162 N50: 100704
# GCF_001746365.1 removed. Contigs: 132 N50: 137390
# GCF_001748305.1 removed. Contigs: 262 N50: 56991
# GCF_001751245.1 removed. Contigs: 166 N50: 132276
# GCF_001751255.1 removed. Contigs: 731 N50: 19859
# GCF_001751305.1 removed. Contamination: 6.91 Completeness: 97.99
# GCF_001756925.1 removed. Contigs: 320 N50: 51843
# GCF_001865245.1 removed. Contigs: 240 N50: 49045
# GCF_001865255.1 removed. Contigs: 876 N50: 12619
# GCF_001866645.1 removed. Contigs: 166 N50: 99963
# GCF_001866665.1 removed. Contigs: 218 N50: 159229
# GCF_001866675.1 removed. Contigs: 174 N50: 162032
# GCF_001879105.1 removed. Contigs: 206 N50: 45324
# GCF_001906585.1 removed. Contigs: 170 N50: 110055
# GCF_001941265.1 removed. Contigs: 1211 N50: 16535
# GCF_001941275.1 removed. Contigs: 983 N50: 20309
# GCF_001941285.1 removed. Contigs: 1073 N50: 20017
# GCF_001941325.1 removed. Contigs: 993 N50: 19323
# GCF_001949645.1 removed. Contigs: 259 N50: 85309
# GCF_001953875.1 removed. Contigs: 208 N50: 63430
# GCF_001969965.1 removed. Contigs: 646 N50: 28947
# GCF_002005565.1 removed. Contigs: 170 N50: 99308
# GCF_002007125.1 removed. Contigs: 127 N50: 183690
# GCF_002078235.1 removed. Contigs: 986 N50: 15779
# GCF_002114215.1 removed. Contigs: 1513 N50: 10426
# GCF_002119195.1 removed. Contigs: 126 N50: 114666
# GCF_002119225.1 removed. Contigs: 352 N50: 30888
# GCF_002148965.1 removed. Contigs: 870 N50: 21344
# GCF_002150735.1 removed. Contigs: 736 N50: 27371
# GCF_002150845.1 removed. Contigs: 852 N50: 18609
# GCF_002154275.1 removed. Contigs: 1258 N50: 17428
# GCF_002154345.1 removed. Contigs: 846 N50: 17809
# GCF_002154375.1 removed. Contigs: 1135 N50: 13850
# GCF_002154385.1 removed. Contigs: 594 N50: 23195
# GCF_002154415.1 removed. Contigs: 874 N50: 14867
# GCF_002154445.1 removed. Contigs: 1555 N50: 6532
# GCF_002154495.1 removed. Contigs: 981 N50: 16615
# GCF_002154505.1 removed. Contigs: 824 N50: 27358
# GCF_002154555.1 removed. Contigs: 1088 N50: 14213
# GCF_002154575.1 removed. Contigs: 946 N50: 17336
# GCF_002154605.1 removed. Contigs: 1328 N50: 17761
# GCF_002154615.1 removed. Contigs: 926 N50: 12194
# GCF_002154675.1 removed. Contigs: 897 N50: 22762
# GCF_002155725.1 removed. Contigs: 1401 N50: 14164
# GCF_002155735.1 removed. Contigs: 1748 N50: 10223
# GCF_002155765.1 removed. Contigs: 1566 N50: 11589
# GCF_002155885.1 removed. Contigs: 1370 N50: 17562
# GCF_002155895.1 removed. Contigs: 808 N50: 20398
# GCF_002155905.1 removed. Contigs: 1107 N50: 15457
# GCF_002155915.1 removed. Contigs: 595 N50: 21010
# GCF_002156055.1 removed. Contigs: 757 N50: 18965
# GCF_002156075.1 removed. Contigs: 1568 N50: 12428
# GCF_002156095.1 removed. Contigs: 692 N50: 27328
# GCF_002156145.1 removed. Contigs: 1243 N50: 12317
# GCF_002158965.1 removed. Contigs: 650 N50: 22501
# GCF_002224125.1 removed. Contigs: 127 N50: 254229
# GCF_002242735.1 removed. Contigs: 285 N50: 78584
# GCF_002242805.1 removed. Contigs: 242 N50: 262623
# GCF_002276245.1 removed. Contigs: 581 N50: 26110
# GCF_002277855.1 removed. Contigs: 679 N50: 34813
# GCF_002286695.1 removed. Contigs: 714 N50: 21466
# GCF_002289305.1 removed. Contigs: 1153 N50: 8176
# GCF_002289335.1 removed. Contigs: 1053 N50: 10498
# GCF_002291145.1 removed. Contigs: 222 N50: 103532
# GCF_002317005.1 removed. Contigs: 1114 N50: 9968
# GCF_002317025.1 removed. Contigs: 1028 N50: 11431
# GCF_002317035.1 removed. Contigs: 957 N50: 12358
# GCF_002335465.1 removed. Contigs: 131 N50: 304660
# GCF_002382885.1 removed. Contigs: 189 N50: 85451
# GCF_002551015.1 removed. Contigs: 1400 N50: 11691
# GCF_002551045.1 removed. Contigs: 1178 N50: 15426
# GCF_002551055.1 removed. Contigs: 892 N50: 20004
# GCF_002551065.1 removed. Contigs: 337 N50: 42533
# GCF_002551105.1 removed. Contigs: 555 N50: 29441
# GCF_002551135.1 removed. Contigs: 504 N50: 31001
# GCF_002551145.1 removed. Contigs: 559 N50: 29129
# GCF_002551175.1 removed. Contigs: 214 N50: 95964
# GCF_002551185.1 removed. Contigs: 494 N50: 32985
# GCF_002551215.1 removed. Contigs: 784 N50: 21085
# GCF_002551225.1 removed. Contigs: 670 N50: 24278
# GCF_002551235.1 removed. Contigs: 619 N50: 25776
# GCF_002551245.1 removed. Contigs: 629 N50: 26146
# GCF_002551295.1 removed. Contigs: 228 N50: 70290
# GCF_002551305.1 removed. Contigs: 245 N50: 81082
# GCF_002551335.1 removed. Contigs: 918 N50: 15476
# GCF_002551345.1 removed. Contigs: 164 N50: 83606
# GCF_002551375.1 removed. Contigs: 164 N50: 103747
# GCF_002551415.1 removed. Contigs: 619 N50: 23604
# GCF_002551425.1 removed. Contigs: 1410 N50: 14459
# GCF_002551435.1 removed. Contigs: 145 N50: 109544
# GCF_002551465.1 removed. Contigs: 222 N50: 80138
# GCF_002551475.1 removed. Contigs: 222 N50: 63977
# GCF_002573955.1 removed. Contigs: 663 N50: 20124
# GCF_002705665.1 removed. Contigs: 106 N50: 261762
# GCF_002727115.1 removed. Contamination: 7.93 Completeness: 99.64
# GCF_002843305.1 removed. Contigs: 119 N50: 127012
# GCF_002844215.1 removed. Contigs: 182 N50: 84238
# GCF_002891435.1 removed. Contigs: 1024 N50: 17129
# GCF_002891865.1 removed. Contamination: 5.26 Completeness: 100.0
# GCF_002907485.1 removed. Contigs: 111 N50: 148637
# GCF_002910755.1 removed. Contigs: 639 N50: 18032
# GCF_002910795.1 removed. Contigs: 1592 N50: 7255
# GCF_002910815.1 removed. Contigs: 1369 N50: 7818
# GCF_002910825.1 removed. Contigs: 1057 N50: 13915
# GCF_002910855.1 removed. Contigs: 910 N50: 12271
# GCF_002910875.1 removed. Contigs: 388 N50: 41121
# GCF_002910895.1 removed. Contigs: 496 N50: 30992
# GCF_002910905.1 removed. Contigs: 311 N50: 45758
# GCF_002910915.1 removed. Contigs: 195 N50: 76497
# GCF_002910935.1 removed. Contigs: 580 N50: 26253
# GCF_002910985.1 removed. Contigs: 609 N50: 24967
# GCF_002911015.1 removed. Contigs: 277 N50: 75083
# GCF_002920535.1 removed. Contigs: 193 N50: 85687
# GCF_002920575.1 removed. Contigs: 245 N50: 65242
# GCF_002920615.1 removed. Contigs: 116 N50: 235045
# GCF_002920635.1 removed. Contigs: 279 N50: 60931
# GCF_002939385.1 removed. Contigs: 190 N50: 81228
# GCF_002953255.1 removed. Contamination: 0.79 Completeness: 86.61
# GCF_002954775.1 removed. Contamination: 0.79 Completeness: 88.84
# GCF_002966105.1 removed. Contigs: 150 N50: 424085
# GCF_002982015.1 removed. Contigs: 748 N50: 13225
# GCF_003013745.1 removed. Contigs: 236 N50: 70608
# GCF_003073355.1 removed. Contigs: 396 N50: 38992
# GCF_003122345.2 removed. Contigs: 150 N50: 459751
# GCF_003129505.1 removed. Contigs: 281 N50: 83624
# GCF_003143855.1 removed. Contigs: 169 N50: 160697
# GCF_003173635.1 removed. Contigs: 1956 N50: 6332
# GCF_003173645.1 removed. Contigs: 1836 N50: 7225
# GCF_003205575.1 removed. Contigs: 439 N50: 76804
# GCF_003236365.1 removed. Contigs: 1200 N50: 12812
# GCF_003258295.1 removed. Contigs: 281 N50: 56286
# GCF_003259365.1 removed. Contigs: 111 N50: 362350
# GCF_003268555.1 removed. Contigs: 1013 N50: 17536
# GCF_003270085.1 removed. Contigs: 298 N50: 33934
# GCF_003311645.1 removed. Contigs: 296 N50: 121713
# GCF_003344905.1 removed. Contigs: 118 N50: 229990
# GCF_003346515.1 removed. Contigs: 480 N50: 28347
# GCF_003389455.1 removed. Contigs: 486 N50: 33076
# GCF_003429565.1 removed. Contigs: 239 N50: 58844
# GCF_003501885.1 removed. Contigs: 466 N50: 30911
# GCF_003568675.1 removed. Contigs: 352 N50: 59981
# GCF_003584805.1 removed. Contigs: 1015 N50: 18661
# GCF_003584815.1 removed. Contigs: 1211 N50: 13310
# GCF_003584825.1 removed. Contigs: 1078 N50: 17518
# GCF_003626645.1 removed. Contigs: 247 N50: 541812
# GCF_003671675.1 removed. Contigs: 648 N50: 18398
# GCF_003671685.1 removed. Contigs: 617 N50: 23688
# GCF_003671755.1 removed. Contigs: 833 N50: 15941
# GCF_003688995.1 removed. Contigs: 137 N50: 212672
# GCF_003696235.1 removed. Contigs: 428 N50: 25828
# GCF_003721215.1 removed. Contigs: 886 N50: 24675
# GCF_003851625.1 removed. Contigs: 292 N50: 103610
# GCF_003933485.1 removed. Contigs: 131 N50: 460998
# GCF_003933965.1 removed. Contigs: 1347 N50: 13705
# GCF_003947455.1 removed. Contigs: 465 N50: 37062
# GCF_003947555.1 removed. Contigs: 790 N50: 23520
# GCF_003947585.1 removed. Contigs: 975 N50: 21249
# GCF_003949505.1 removed. Contigs: 296 N50: 54438
# GCF_003949535.1 removed. Contigs: 1104 N50: 13955
# GCF_003949665.1 removed. Contigs: 963 N50: 17391
# GCF_003949695.1 removed. Contigs: 880 N50: 22710
# GCF_003949795.1 removed. Contigs: 821 N50: 20356
# GCF_003949805.1 removed. Contigs: 753 N50: 19785
# GCF_003949835.1 removed. Contamination: 6.18 Completeness: 100.0
# GCF_003949875.1 removed. Contigs: 118 N50: 177740
# GCF_003949895.1 removed. Contigs: 1916 N50: 8678
# GCF_003949955.1 removed. Contigs: 926 N50: 14397
# GCF_003977835.1 removed. Contigs: 214 N50: 141168
# GCF_003977875.1 removed. Contigs: 619 N50: 37166
# GCF_003984785.1 removed. Contigs: 619 N50: 25940
# GCF_003999195.1 removed. Contigs: 412 N50: 40353
# GCF_004023625.1 removed. Contigs: 131 N50: 275254
# GCF_004078575.1 removed. Contigs: 1057 N50: 11575
# GCF_004117935.1 removed. Contigs: 181 N50: 83322
# GCF_004122735.1 removed. Contigs: 289 N50: 54690
# GCF_004122755.1 removed. Contigs: 277 N50: 33909
# GCF_004151105.1 removed. Contigs: 172 N50: 203880
# GCF_004187715.1 removed. Contigs: 171 N50: 601559
# GCF_004196055.1 removed. Contigs: 146 N50: 113214
# GCF_004196115.1 removed. Contigs: 147 N50: 97051
# GCF_004196335.1 removed. Contigs: 333 N50: 314273
# GCF_004212445.1 removed. Contigs: 235 N50: 90629
# GCF_004305975.1 removed. Contigs: 752 N50: 18370
# GCF_004320085.1 removed. Contigs: 962 N50: 15111
# GCF_004348315.1 removed. Contigs: 703 N50: 17808
# GCF_004348415.1 removed. Contigs: 951 N50: 13702
# GCF_004403015.1 removed. Contigs: 175 N50: 87699
# GCF_004684775.1 removed. Contigs: 630 N50: 25361
# GCF_004684805.1 removed. Contigs: 801 N50: 16138
# GCF_004768505.1 removed. Contigs: 120 N50: 489196
# GCF_004794175.1 removed. Contigs: 807 N50: 15942
# GCF_004794975.1 removed. Contigs: 110 N50: 210358
# GCF_004795015.1 removed. Contigs: 115 N50: 114260
# GCF_004795035.1 removed. Contigs: 113 N50: 166249
# GCF_004795055.1 removed. Contigs: 412 N50: 166286
# GCF_004795115.1 removed. Contigs: 106 N50: 235884
# GCF_004795155.1 removed. Contigs: 219 N50: 72620
# GCF_005047355.1 removed. Contigs: 389 N50: 131738
# GCF_005280195.1 removed. Contigs: 111 N50: 326353
# GCF_005768555.2 removed. Contigs: 352 N50: 59982
# GCF_005786655.1 removed. Contigs: 168 N50: 137451
# GCF_005981925.1 removed. Contigs: 795 N50: 18694
# GCF_005981935.1 removed. Contigs: 1451 N50: 9479
# GCF_005981965.1 removed. Contigs: 823 N50: 17998
# GCF_006335115.1 removed. Contigs: 186 N50: 117311
# GCF_006539165.1 removed. Contigs: 197 N50: 142848
# GCF_006539185.1 removed. Contigs: 147 N50: 146657
# GCF_006539505.1 removed. Contigs: 218 N50: 109659
# GCF_006547165.1 removed. Contigs: 178 N50: 144065
# GCF_006547175.1 removed. Contigs: 345 N50: 60995
# GCF_006547185.1 removed. Contigs: 377 N50: 58885
# GCF_007050945.1 removed. Contigs: 109 N50: 375098
# GCF_007096885.1 removed. Contigs: 143 N50: 141317
# GCF_007097205.2 removed. Contigs: 769 N50: 15903
# GCF_007097665.2 removed. Contigs: 1861 N50: 5488
# GCF_007280575.1 removed. Contigs: 814 N50: 16345
# GCF_007280585.1 removed. Contigs: 1118 N50: 11372
# GCF_007677905.1 removed. Contamination: 12.970456661443787 Completeness: 100.0
# GCF_007679265.1 removed. Contigs: 138 N50: 224298
# GCF_007679425.1 removed. Contigs: 141 N50: 221527
# GCF_007896895.1 removed. Contigs: 210 N50: 70083
# GCF_008039505.1 removed. Contigs: 188 N50: 220695
# GCF_008042045.1 removed. Contigs: 292 N50: 1120392
# GCF_008042075.1 removed. Contigs: 190 N50: 1367314
# GCF_008042115.1 removed. Contigs: 301 N50: 493345
# GCF_008042125.1 removed. Contigs: 261 N50: 388359
# GCF_008042145.1 removed. Contigs: 346 N50: 468649
# GCF_008042155.1 removed. Contigs: 190 N50: 1700478
# GCF_008042275.1 removed. Contigs: 140 N50: 4652464
# GCF_008086975.1 removed. Contigs: 882 N50: 16068
# GCF_008087005.1 removed. Contigs: 930 N50: 20394
# GCF_008120935.1 removed. Contigs: 309 N50: 307497
# GCF_008180165.1 removed. Contigs: 729 N50: 28163
# GCF_008271805.1 removed. Contigs: 174 N50: 110600
# GCF_008369065.1 removed. Contigs: 309 N50: 296590
# GCF_008386495.1 removed. Contigs: 183 N50: 115964
# GCF_008632535.1 removed. Contigs: 546 N50: 28351
# GCF_008806595.1 removed. Contigs: 105 N50: 198006
# GCF_008868685.1 removed. Contigs: 127 N50: 170991
# GCF_008905045.1 removed. Contigs: 200 N50: 138999
# GCF_008932075.1 removed. Contigs: 121 N50: 161029
# GCF_009208535.1 removed. Contigs: 169 N50: 164101
# GCF_009377175.1 removed. Contigs: 563 N50: 32765
# GCF_009377185.1 removed. Contigs: 1115 N50: 15786
# GCF_009377205.1 removed. Contigs: 939 N50: 17201
# GCF_009377235.1 removed. Contigs: 544 N50: 34036
# GCF_009600885.1 removed. Contigs: 209 N50: 91474
# GCF_009600895.1 removed. Contigs: 412 N50: 37935
# GCF_009604385.1 removed. Contigs: 106 N50: 161565
# GCF_009709555.1 removed. Contigs: 253 N50: 97082
# GCF_009735685.1 removed. Contigs: 431 N50: 32682
# GCF_009739225.1 removed. Contigs: 618 N50: 22652
# GCF_009739465.1 removed. Contamination: 12.07 Completeness: 100.0
# GCF_009862025.1 removed. Contigs: 472 N50: 35596
# GCF_009862125.1 removed. Contamination: 4.72 Completeness: 87.98
# GCF_009862225.1 removed. Contigs: 120 N50: 169228
# GCF_009862265.1 removed. Contigs: 115 N50: 141016
# GCF_009862305.1 removed. Contigs: 111 N50: 362350
# GCF_009862355.1 removed. Contamination: 6.1 Completeness: 85.85
# GCF_009862405.1 removed. Contigs: 219 N50: 55778
# GCF_009862465.1 removed. Contigs: 351 N50: 38665
# GCF_009862475.1 removed. Contigs: 266 N50: 54854
# GCF_009862505.1 removed. Contigs: 193 N50: 181994
# GCF_009862515.1 removed. Contigs: 1579 N50: 9144
# GCF_009862625.1 removed. Contigs: 731 N50: 23142
# GCF_009862635.1 removed. Contamination: 8.75 Completeness: 93.67
# GCF_009862685.1 removed. Contamination: 6.54 Completeness: 98.25
# GCF_009862765.1 removed. Contamination: 17.67 Completeness: 94.54
# GCF_009862825.1 removed. Contigs: 959 N50: 13297
# GCF_009862845.1 removed. Contamination: 7.31 Completeness: 92.54
# GCF_009862935.1 removed. Contigs: 453 N50: 40361
# GCF_009863025.1 removed. Contigs: 731 N50: 18077
# GCF_009863035.1 removed. Contigs: 1065 N50: 13238
# GCF_009863045.1 removed. Contigs: 762 N50: 21477
# GCF_009863085.1 removed. Contigs: 106 N50: 261762
# GCF_009863095.1 removed. Contigs: 460 N50: 38736
# GCF_009863125.1 removed. Contigs: 142 N50: 266092
# GCF_009863145.1 removed. Contigs: 111 N50: 142272
# GCF_009863165.1 removed. Contigs: 128 N50: 129868
# GCF_009863175.1 removed. Contigs: 174 N50: 88536
# GCF_009863225.1 removed. Contigs: 254 N50: 59002
# GCF_009864805.1 removed. Contamination: 5.79 Completeness: 99.47
# GCF_009864855.1 removed. Contigs: 1923 N50: 5700
# GCF_009864985.1 removed. Contigs: 811 N50: 17565
# GCF_009865085.1 removed. Contigs: 111 N50: 113608
# GCF_009865165.1 removed. Contigs: 837 N50: 21184
# GCF_009865175.1 removed. Contigs: 993 N50: 17668
# GCF_009865205.1 removed. Contigs: 573 N50: 22006
# GCF_009865215.1 removed. Contigs: 1646 N50: 14460
# GCF_009865265.1 removed. Contigs: 1765 N50: 9124
# GCF_009865275.1 removed. Contigs: 397 N50: 35205
# GCF_009865385.1 removed. Contigs: 809 N50: 21568
# GCF_009865405.1 removed. Contigs: 1270 N50: 13092
# GCF_009865425.1 removed. Contigs: 777 N50: 17651
# GCF_009865475.1 removed. Contigs: 462 N50: 44392
# GCF_009865505.1 removed. Contigs: 1872 N50: 7364
# GCF_009865545.1 removed. Contigs: 1059 N50: 14193
# GCF_009865565.1 removed. Contigs: 500 N50: 36788
# GCF_009865585.1 removed. Contigs: 1902 N50: 8560
# GCF_009865595.1 removed. Contamination: 7.48 Completeness: 96.57
# GCF_009865605.1 removed. Contamination: 6.57 Completeness: 96.73
# GCF_009866455.1 removed. Contigs: 165 N50: 153923
# GCF_009870065.1 removed. Contigs: 1157 N50: 10784
# GCF_009870095.1 removed. Contigs: 620 N50: 27471
# GCF_009872515.1 removed. Contigs: 1059 N50: 24858
# GCF_009872535.1 removed. Contigs: 1124 N50: 15738
# GCF_009872555.1 removed. Contigs: 369 N50: 50997
# GCF_009872565.1 removed. Contigs: 560 N50: 25468
# GCF_009873275.1 removed. Contamination: 5.15 Completeness: 89.99
# GCF_009908195.1 removed. Contigs: 794 N50: 16908
# GCF_009916105.1 removed. Contigs: 854 N50: 17537
# GCF_010119355.1 removed. Contigs: 170 N50: 87030
# GCF_010548045.1 removed. Contigs: 426 N50: 37429
# GCF_010548075.1 removed. Contigs: 1631 N50: 11324
# GCF_010548115.1 removed. Contigs: 812 N50: 30742
# GCF_010548145.1 removed. Contigs: 521 N50: 25717
# GCF_010548175.1 removed. Contigs: 756 N50: 22224
# GCF_010548185.1 removed. Contigs: 1740 N50: 9141
# GCF_010548215.1 removed. Contigs: 1869 N50: 9238
# GCF_010548245.1 removed. Contigs: 1202 N50: 14469
# GCF_010548275.1 removed. Contigs: 183 N50: 217140
# GCF_010548305.1 removed. Contigs: 134 N50: 336850
# GCF_010548325.1 removed. Contigs: 268 N50: 163002
# GCF_010548345.1 removed. Contigs: 325 N50: 152276
# GCF_010548375.1 removed. Contigs: 923 N50: 394215
# GCF_010548385.1 removed. Contigs: 1070 N50: 16758
# GCF_010548435.1 removed. Contigs: 981 N50: 18965
# GCF_010548465.1 removed. Contigs: 908 N50: 16387
# GCF_010548475.1 removed. Contamination: 5.53 Completeness: 99.14
# GCF_010548505.1 removed. Contigs: 150 N50: 124267
# GCF_010548515.1 removed. Contigs: 104 N50: 184012
# GCF_010548525.1 removed. Contigs: 1499 N50: 13264
# GCF_010548565.1 removed. Contigs: 1034 N50: 16154
# GCF_010548575.1 removed. Contigs: 551 N50: 34865
# GCF_010548605.1 removed. Contigs: 583 N50: 28537
# GCF_010548615.1 removed. Contigs: 1117 N50: 15550
# GCF_010548665.1 removed. Contigs: 1956 N50: 8187
# GCF_010548675.1 removed. Contigs: 371 N50: 42839
# GCF_010548705.1 removed. Contigs: 415 N50: 41768
# GCF_010548715.1 removed. Contigs: 644 N50: 24401
# GCF_010548725.1 removed. Contigs: 652 N50: 20748
# GCF_010550245.1 removed. Contamination: 5.65 Completeness: 100.0
# GCF_010550325.1 removed. Contigs: 1317 N50: 14483
# GCF_010550365.1 removed. Contigs: 1799 N50: 7286
# GCF_010550375.1 removed. Contigs: 635 N50: 26576
# GCF_010550405.1 removed. Contigs: 1642 N50: 10146
# GCF_010550435.1 removed. Contamination: 8.62 Completeness: 98.28
# GCF_010550505.1 removed. Contigs: 1226 N50: 13806
# GCF_010550525.1 removed. Contigs: 1440 N50: 12106
# GCF_010550535.1 removed. Contigs: 672 N50: 23209
# GCF_010550605.1 removed. Contigs: 537 N50: 31997
# GCF_010550625.1 removed. Contigs: 613 N50: 22756
# GCF_010550645.1 removed. Contigs: 1631 N50: 8492
# GCF_010892295.1 removed. Contigs: 174 N50: 116762
# GCF_011008945.1 removed. Contigs: 1096 N50: 19372
# GCF_011044975.1 removed. Contigs: 613 N50: 28409
# GCF_011044995.1 removed. Contigs: 505 N50: 31168
# GCF_011045015.1 removed. Contigs: 496 N50: 41950
# GCF_011045025.1 removed. Contigs: 532 N50: 39427
# GCF_011045075.1 removed. Contigs: 1141 N50: 12556
# GCF_011055525.1 removed. Contigs: 143 N50: 110457
# GCF_011170145.1 removed. Contamination: 7.5 Completeness: 99.89
# GCF_011421595.1 removed. Contigs: 424 N50: 28352
# GCF_011766325.1 removed. Contigs: 120 N50: 264498
# GCF_012033735.1 removed. Contigs: 482 N50: 20985
# GCF_012033785.1 removed. Contigs: 547 N50: 17710
# GCF_012034175.1 removed. Contigs: 101 N50: 216213
# GCF_012034295.1 removed. Contigs: 914 N50: 15297
# GCF_012034305.1 removed. Contigs: 1252 N50: 12619
# GCF_012034385.1 removed. Contigs: 474 N50: 20130
# GCF_012328665.1 removed. Contigs: 791 N50: 15728
# GCF_013004455.1 removed. Contigs: 512 N50: 29851
# GCF_013018355.1 removed. Contigs: 382 N50: 131299
# GCF_013030945.1 removed. Contigs: 238 N50: 127665
# GCF_013044505.1 removed. Contigs: 569 N50: 40558
# GCF_013055795.1 removed. Contigs: 105 N50: 166849
# GCF_013177615.1 removed. Contigs: 211 N50: 147764
# GCF_013302945.1 removed. Contamination: 0.0 Completeness: 8.620689655172415
# GCF_013345665.1 removed. Contamination: 6.32 Completeness: 100.0
# GCF_013357925.1 removed. Contigs: 240 N50: 543791
# GCF_013357935.1 removed. Contigs: 333 N50: 44555
# GCF_013357965.1 removed. Contigs: 570 N50: 29740
# GCF_013358025.1 removed. Contigs: 480 N50: 32071
# GCF_013358045.1 removed. Contigs: 623 N50: 29740
# GCF_013358055.1 removed. Contigs: 904 N50: 29164
# GCF_013358065.1 removed. Contigs: 515 N50: 28882
# GCF_013358105.1 removed. Contigs: 502 N50: 29830
# GCF_013358115.1 removed. Contigs: 453 N50: 34436
# GCF_013358135.1 removed. Contigs: 493 N50: 30076
# GCF_013358155.1 removed. Contigs: 508 N50: 29219
# GCF_013358165.1 removed. Contigs: 614 N50: 26021
# GCF_013358235.1 removed. Contigs: 563 N50: 25668
# GCF_013358245.1 removed. Contigs: 516 N50: 29143
# GCF_013358305.1 removed. Contigs: 549 N50: 24483
# GCF_013358325.1 removed. Contigs: 523 N50: 29656
# GCF_013358335.1 removed. Contigs: 520 N50: 31126
# GCF_013362995.1 removed. Contigs: 469 N50: 26924
# GCF_013363485.1 removed. Contigs: 658 N50: 36637
# GCF_013363585.1 removed. Contigs: 447 N50: 44999
# GCF_013363615.1 removed. Contigs: 280 N50: 148248
# GCF_013363655.1 removed. Contigs: 258 N50: 108202
# GCF_013363675.1 removed. Contigs: 186 N50: 118325
# GCF_013363715.1 removed. Contigs: 330 N50: 65929
# GCF_013371965.1 removed. Contigs: 187 N50: 107473
# GCF_013387495.1 removed. Contigs: 160 N50: 191302
# GCF_013401435.1 removed. Contigs: 723 N50: 22797
# GCF_013421635.1 removed. Contigs: 1475 N50: 6270
# GCF_013433285.1 removed. Contigs: 168 N50: 147083
# GCF_013618515.1 removed. Contigs: 748 N50: 15600
# GCF_013618545.1 removed. Contigs: 473 N50: 26709
# GCF_013778455.1 removed. Contigs: 109 N50: 260785
# GCF_013870495.1 removed. Contigs: 1608 N50: 10913
# GCF_013870515.1 removed. Contigs: 497 N50: 20451
# GCF_013870535.1 removed. Contamination: 0.79 Completeness: 87.81
# GCF_013870595.1 removed. Contigs: 1416 N50: 7656
# GCF_013912435.1 removed. Contigs: 231 N50: 144039
# GCF_014141525.1 removed. Contigs: 1643 N50: 6206
# GCF_014141535.1 removed. Contigs: 1801 N50: 5021
# GCF_014156695.1 removed. Contigs: 1002 N50: 10866
# GCF_014257025.1 removed. Contigs: 210 N50: 119198
# GCF_014284355.1 removed. Contigs: 936 N50: 15211
# GCF_014284425.1 removed. Contigs: 1174 N50: 13902
# GCF_014493765.1 removed. Contigs: 178 N50: 363618
# GCF_014495685.1 removed. Contigs: 284 N50: 80030
# GCF_014534645.1 removed. Contigs: 241 N50: 166916
# GCF_014596445.1 removed. Contigs: 277 N50: 67094
# GCF_014596465.1 removed. Contigs: 642 N50: 32587
# GCF_014596505.1 removed. Contigs: 162 N50: 78797
# GCF_014596515.1 removed. Contamination: 7.11 Completeness: 92.11
# GCF_014596525.1 removed. Contigs: 116 N50: 106767
# GCF_014596915.1 removed. Contigs: 121 N50: 264765
# GCF_014645815.1 removed. Contigs: 129 N50: 307198
# GCF_014646055.1 removed. Contigs: 173 N50: 225409
# GCF_014646095.1 removed. Contigs: 132 N50: 247165
# GCF_014646275.1 removed. Contigs: 141 N50: 191127
# GCF_014647675.1 removed. Contigs: 108 N50: 262738
# GCF_014647695.1 removed. Contigs: 209 N50: 314084
# GCF_014647715.1 removed. Contigs: 130 N50: 73728
# GCF_014647875.1 removed. Contigs: 285 N50: 168452
# GCF_014648555.1 removed. Contigs: 125 N50: 208654
# GCF_014648615.1 removed. Contigs: 145 N50: 357856
# GCF_014648655.1 removed. Contigs: 244 N50: 195965
# GCF_014648695.1 removed. Contigs: 165 N50: 201243
# GCF_014648795.1 removed. Contigs: 130 N50: 132417
# GCF_014648915.1 removed. Contigs: 103 N50: 258264
# GCF_014649015.1 removed. Contigs: 221 N50: 388913
# GCF_014649035.1 removed. Contigs: 102 N50: 183557
# GCF_014649235.1 removed. Contigs: 134 N50: 369678
# GCF_014649475.1 removed. Contigs: 128 N50: 243992
# GCF_014649495.1 removed. Contigs: 101 N50: 364515
# GCF_014649515.1 removed. Contigs: 139 N50: 465971
# GCF_014649535.1 removed. Contigs: 114 N50: 237536
# GCF_014649595.1 removed. Contigs: 132 N50: 348767
# GCF_014649635.1 removed. Contigs: 179 N50: 253435
# GCF_014649655.1 removed. Contigs: 181 N50: 194407
# GCF_014649775.1 removed. Contigs: 167 N50: 346887
# GCF_014649795.1 removed. Contigs: 102 N50: 374786
# GCF_014649815.1 removed. Contigs: 359 N50: 306986
# GCF_014649975.1 removed. Contigs: 118 N50: 347702
# GCF_014650115.1 removed. Contigs: 135 N50: 278653
# GCF_014650135.1 removed. Contigs: 241 N50: 512933
# GCF_014650435.1 removed. Contigs: 139 N50: 452485
# GCF_014650495.1 removed. Contigs: 109 N50: 263071
# GCF_014650595.1 removed. Contigs: 179 N50: 228177
# GCF_014650615.1 removed. Contigs: 111 N50: 245055
# GCF_014650635.1 removed. Contigs: 179 N50: 221021
# GCF_014650655.1 removed. Contigs: 128 N50: 327315
# GCF_014650735.1 removed. Contigs: 272 N50: 185453
# GCF_014650835.1 removed. Contigs: 115 N50: 250279
# GCF_014650855.1 removed. Contigs: 169 N50: 164302
# GCF_014650875.1 removed. Contigs: 296 N50: 140288
# GCF_014650935.1 removed. Contigs: 236 N50: 238207
# GCF_014650955.1 removed. Contigs: 105 N50: 239402
# GCF_014650995.1 removed. Contigs: 153 N50: 263771
# GCF_014651075.1 removed. Contigs: 109 N50: 341741
# GCF_014651115.1 removed. Contigs: 108 N50: 226038
# GCF_014651135.1 removed. Contigs: 108 N50: 181340
# GCF_014651175.1 removed. Contigs: 165 N50: 524601
# GCF_014651195.1 removed. Contigs: 104 N50: 328976
# GCF_014653855.1 removed. Contigs: 163 N50: 190010
# GCF_014654675.1 removed. Contigs: 176 N50: 150732
# GCF_014654935.1 removed. Contigs: 147 N50: 257073
# GCF_014655475.1 removed. Contigs: 150 N50: 198945
# GCF_014655955.1 removed. Contigs: 198 N50: 131717
# GCF_014656075.1 removed. Contigs: 332 N50: 59557
# GCF_014656095.1 removed. Contigs: 354 N50: 45204
# GCF_014656295.1 removed. Contigs: 114 N50: 315753
# GCF_014712245.1 removed. Contigs: 265 N50: 139555
# GCF_014748275.1 removed. Contigs: 344 N50: 431047
# GCF_014852645.1 removed. Contigs: 1180 N50: 9931
# GCF_015475845.1 removed. Contigs: 119 N50: 212980
# GCF_015645455.1 removed. Contigs: 144 N50: 184031
# GCF_015689475.1 removed. Contamination: 5.26 Completeness: 100.0
# GCF_015690355.1 removed. Contamination: 6.84 Completeness: 99.47
# GCF_015912395.1 removed. Contigs: 1688 N50: 9549
# GCF_015912435.1 removed. Contigs: 1938 N50: 8002
# GCF_015912455.1 removed. Contigs: 1196 N50: 9769
# GCF_015912465.1 removed. Contigs: 1242 N50: 9241
# GCF_015912875.1 removed. Contigs: 1712 N50: 9030
# GCF_015912895.1 removed. Contigs: 1935 N50: 7660
# GCF_015912925.1 removed. Contigs: 1857 N50: 8743
# GCF_015912945.1 removed. Contigs: 1850 N50: 8414
# GCF_015912975.1 removed. Contigs: 1190 N50: 9618
# GCF_015912985.1 removed. Contigs: 1341 N50: 8658
# GCF_015912995.1 removed. Contigs: 1163 N50: 9656
# GCF_015999245.1 removed. Contigs: 111 N50: 995929
# GCF_016017415.1 removed. Contigs: 331 N50: 41623
# GCF_016103465.1 removed. Contigs: 1327 N50: 15605
# GCF_016103505.1 removed. Contamination: 12.654135338345869 Completeness: 94.26315789473684
# GCF_016107395.1 removed. Contigs: 475 N50: 152116
# GCF_016464295.1 removed. Contigs: 240 N50: 82658
# GCF_016491645.1 removed. Contigs: 1164 N50: 17257
# GCF_016598475.1 removed. Contigs: 352 N50: 83341
# GCF_016612545.1 removed. Contigs: 833 N50: 30177
# GCF_016612575.1 removed. Contigs: 602 N50: 24967
# GCF_016612605.1 removed. Contigs: 497 N50: 30897
# GCF_016612625.1 removed. Contigs: 757 N50: 31686
# GCF_016612645.1 removed. Contigs: 598 N50: 25388
# GCF_016612655.1 removed. Contigs: 312 N50: 69644
# GCF_016612665.1 removed. Contigs: 552 N50: 26977
# GCF_016612705.1 removed. Contigs: 589 N50: 27955
# GCF_016612725.1 removed. Contigs: 498 N50: 30984
# GCF_016612755.1 removed. Contigs: 357 N50: 41187
# GCF_016612775.1 removed. Contigs: 635 N50: 24564
# GCF_016612805.1 removed. Contigs: 1146 N50: 14743
# GCF_016612825.1 removed. Contigs: 762 N50: 24257
# GCF_016612855.1 removed. Contigs: 537 N50: 41669
# GCF_016613285.1 removed. Contigs: 134 N50: 105553
# GCF_016613335.1 removed. Contigs: 126 N50: 119828
# GCF_016653995.1 removed. Contigs: 622 N50: 27814
# GCF_016654055.1 removed. Contigs: 591 N50: 26144
# GCF_016654065.1 removed. Contigs: 597 N50: 25060
# GCF_016654115.1 removed. Contigs: 543 N50: 43101
# GCF_016741775.1 removed. Contigs: 106 N50: 270358
# GCF_016741855.1 removed. Contigs: 148 N50: 398829
# GCF_016741875.1 removed. Contigs: 253 N50: 229793
# GCF_016741935.1 removed. Contigs: 269 N50: 328265
# GCF_016745505.1 removed. Contigs: 207 N50: 64915
# GCF_016757295.1 removed. Contigs: 369 N50: 99471
# GCF_016834575.1 removed. Contigs: 214 N50: 65020
# GCF_016901035.1 removed. Contigs: 616 N50: 26787
# GCF_016905445.1 removed. Contigs: 583 N50: 33264
# GCF_016921115.1 removed. Contigs: 306 N50: 190774
# GCF_017114865.1 removed. Contigs: 105 N50: 171252
# GCF_017164735.1 removed. Contigs: 715 N50: 16285
# GCF_017315755.1 removed. Contigs: 1769 N50: 21718
# GCF_017353455.1 removed. Contamination: 0.79 Completeness: 85.61
# GCF_017427025.1 removed. Contigs: 1261 N50: 10071
# GCF_017592595.1 removed. Contigs: 135 N50: 272704
# GCF_017614965.1 removed. Contigs: 773 N50: 25652
# GCF_017676365.1 removed. Contigs: 405 N50: 31324
# GCF_017813245.1 removed. Contigs: 402 N50: 35783
# GCF_017948485.1 removed. Contigs: 117 N50: 299478
# GCF_018035285.1 removed. Contigs: 893 N50: 18372
# GCF_018070205.1 removed. Contigs: 143 N50: 171449
# GCF_018070535.1 removed. Contigs: 126 N50: 202649
# GCF_018070565.1 removed. Contigs: 134 N50: 164477
# GCF_018070605.1 removed. Contigs: 245 N50: 66869
# GCF_018070745.1 removed. Contigs: 171 N50: 134500
# GCF_018555775.1 removed. Contigs: 731 N50: 22476
# GCF_018614005.1 removed. Contigs: 102 N50: 149180
# GCF_018614035.1 removed. Contigs: 101 N50: 139003
# GCF_018614055.1 removed. Contigs: 122 N50: 165028
# GCF_018614075.1 removed. Contigs: 149 N50: 74083
# GCF_018614095.1 removed. Contigs: 155 N50: 81888
# GCF_018614105.1 removed. Contigs: 197 N50: 57180
# GCF_018614135.1 removed. Contigs: 250 N50: 42985
# GCF_018614155.1 removed. Contigs: 196 N50: 59624
# GCF_018614185.1 removed. Contigs: 104 N50: 130389
# GCF_018614195.1 removed. Contigs: 127 N50: 142553
# GCF_018614205.1 removed. Contigs: 216 N50: 55601
# GCF_018614355.1 removed. Contigs: 133 N50: 107847
# GCF_018614415.1 removed. Contigs: 217 N50: 60696
# GCF_018614445.1 removed. Contigs: 117 N50: 194125
# GCF_018614475.1 removed. Contigs: 152 N50: 88780
# GCF_018614515.1 removed. Contigs: 102 N50: 202061
# GCF_018614525.1 removed. Contigs: 219 N50: 43578
# GCF_018614585.1 removed. Contamination: 0.0 Completeness: 81.58
# GCF_018614615.1 removed. Contigs: 154 N50: 111385
# GCF_018619165.1 removed. Contigs: 1524 N50: 7331
# GCF_018619185.1 removed. Contigs: 586 N50: 23710
# GCF_018619195.1 removed. Contigs: 1079 N50: 11823
# GCF_018619235.1 removed. Contigs: 1189 N50: 8953
# GCF_018619575.1 removed. Contigs: 101 N50: 143393
# GCF_018638295.1 removed. Contigs: 206 N50: 204147
# GCF_018638305.1 removed. Contigs: 210 N50: 76195
# GCF_018638335.1 removed. Contigs: 179 N50: 98291
# GCF_018883605.1 removed. Contigs: 1379 N50: 17460
# GCF_018927715.1 removed. Contigs: 898 N50: 43214
# GCF_018982965.1 removed. Contigs: 286 N50: 57920
# GCF_019049085.1 removed. Contigs: 256 N50: 109083
# GCF_019049125.1 removed. Contigs: 139 N50: 203454
# GCF_019049165.1 removed. Contamination: 16.849529780564264 Completeness: 100.0
# GCF_019049185.1 removed. Contigs: 175 N50: 110869
# GCF_019049205.1 removed. Contigs: 204 N50: 137950
# GCF_019049225.1 removed. Contigs: 157 N50: 167824
# GCF_019049245.1 removed. Contigs: 243 N50: 201133
# GCF_019049255.1 removed. Contigs: 232 N50: 216656
# GCF_019049285.1 removed. Contigs: 219 N50: 151084
# GCF_019049305.1 removed. Contigs: 259 N50: 93530
# GCF_019049325.1 removed. Contigs: 139 N50: 217020
# GCF_019049345.1 removed. Contamination: 104.3103448275862 Completeness: 100.0
# GCF_019090125.1 removed. Contigs: 699 N50: 28611
# GCF_019090165.1 removed. Contigs: 212 N50: 114510
# GCF_019091445.1 removed. Contigs: 840 N50: 229965
# GCF_019091475.1 removed. Contigs: 568 N50: 212700
# GCF_019104725.1 removed. Contigs: 111 N50: 109407
# GCF_019192735.1 removed. Contigs: 209 N50: 131431
# GCF_019219825.1 removed. Contigs: 153 N50: 222188
# GCF_019303475.1 removed. Contigs: 118 N50: 98878
# GCF_019350955.1 removed. Contigs: 1759 N50: 7641
# GCF_019399205.1 removed. Contigs: 653 N50: 29528
# GCF_019399235.1 removed. Contigs: 695 N50: 26939
# GCF_019400875.1 removed. Contigs: 881 N50: 13615
# GCF_019400985.1 removed. Contigs: 763 N50: 20623
# GCF_019456635.1 removed. Contigs: 373 N50: 100604
# GCF_019641555.1 removed. Contigs: 1020 N50: 17661
# GCF_019710745.1 removed. Contigs: 212 N50: 148377
# GCF_019733235.1 removed. Contigs: 106 N50: 281159
# GCF_019733245.1 removed. Contigs: 441 N50: 35025
# GCF_019857225.1 removed. Contigs: 190 N50: 119887
# GCF_019890635.1 removed. Contigs: 150 N50: 95602
# GCF_019890645.1 removed. Contigs: 174 N50: 157308
# GCF_019890725.1 removed. Contigs: 171 N50: 116494
# GCF_020024005.1 removed. Contigs: 494 N50: 23973
# GCF_020037025.1 removed. Contigs: 587 N50: 41451
# GCF_020103755.1 removed. Contigs: 1295 N50: 13306
# GCF_020166595.1 removed. Contigs: 1079 N50: 14701
# GCF_020176795.1 removed. Contigs: 991 N50: 15698
# GCF_020177475.1 removed. Contigs: 1018 N50: 12009
# GCF_020181035.1 removed. Contigs: 104 N50: 352661
# GCF_020312235.1 removed. Contigs: 120 N50: 129602
# GCF_020312255.1 removed. Contigs: 129 N50: 97815
# GCF_020312265.1 removed. Contigs: 173 N50: 90653
# GCF_020312315.1 removed. Contigs: 112 N50: 113910
# GCF_020328095.1 removed. Contigs: 297 N50: 62247
# GCF_020400585.1 removed. Contigs: 112 N50: 269769
# GCF_020400595.1 removed. Contigs: 216 N50: 193034
# GCF_020400605.1 removed. Contigs: 137 N50: 230881
# GCF_020400685.1 removed. Contigs: 113 N50: 400654
# GCF_020400725.1 removed. Contigs: 229 N50: 78472
# GCF_020400825.1 removed. Contigs: 188 N50: 203412
# GCF_020404845.1 removed. Contigs: 169 N50: 130065
# GCF_020521255.1 removed. Contamination: 5.24 Completeness: 99.58
# GCF_020521295.1 removed. Contamination: 6.4 Completeness: 98.87
# GCF_020532625.1 removed. Contigs: 284 N50: 38913
# GCF_020532645.1 removed. Contigs: 169 N50: 106707
# GCF_020564935.1 removed. Contigs: 133 N50: 117612
# GCF_020685565.1 removed. Contigs: 106 N50: 362883
# GCF_020740835.1 removed. Contigs: 1076 N50: 12946
# GCF_020740895.1 removed. Contigs: 792 N50: 17091
# GCF_020741675.1 removed. Contigs: 148 N50: 80118
# GCF_020819595.1 removed. Contigs: 141 N50: 364153
# GCF_020861705.1 removed. Contigs: 113 N50: 237932
# GCF_020873855.1 removed. Contigs: 159 N50: 490332
# GCF_020873925.1 removed. Contigs: 102 N50: 255674
# GCF_020881015.1 removed. Contigs: 440 N50: 214941
# GCF_020907985.1 removed. Contigs: 150 N50: 134447
# GCF_020991365.1 removed. Contigs: 200 N50: 217664
# GCF_021083325.1 removed. Contigs: 182 N50: 69524
# GCF_021228125.1 removed. Contigs: 108 N50: 326773
# GCF_021228305.1 removed. Contigs: 115 N50: 523938
# GCF_021233395.1 removed. Contamination: 5.26 Completeness: 100.0
# GCF_021246025.1 removed. Contamination: 5.79 Completeness: 100.0
# GCF_021300715.1 removed. Contigs: 289 N50: 55964
# GCF_021366495.1 removed. Contigs: 142 N50: 183934
# GCF_021432205.1 removed. Contigs: 1133 N50: 15125
# GCF_021432215.1 removed. Contigs: 1377 N50: 10652
# GCF_021432225.1 removed. Contigs: 1214 N50: 12424
# GCF_021432285.1 removed. Contigs: 1245 N50: 12220
# GCF_021442405.1 removed. Contigs: 254 N50: 47382
# GCF_021442415.1 removed. Contigs: 296 N50: 42201
# GCF_021462265.1 removed. Contigs: 253 N50: 185809
# GCF_021462825.1 removed. Contigs: 125 N50: 202410
# GCF_021474405.1 removed. Contigs: 309 N50: 50087
# GCF_021474425.1 removed. Contigs: 670 N50: 31546
# GCF_021538775.1 removed. Contigs: 116 N50: 289470
# GCF_021538815.1 removed. Contigs: 291 N50: 49328
# GCF_021538835.1 removed. Contigs: 401 N50: 37309
# GCF_021538875.1 removed. Contigs: 391 N50: 40525
# GCF_021538895.1 removed. Contigs: 281 N50: 70511
# GCF_021545335.1 removed. Contamination: 1.07 Completeness: 75.86
# GCF_021556455.1 removed. Contigs: 811 N50: 12419
# GCF_021696945.1 removed. Contigs: 219 N50: 63493
# GCF_021890875.1 removed. Contigs: 271 N50: 86830
# GCF_021892415.1 removed. Contigs: 586 N50: 33554
# GCF_022015835.1 removed. Contigs: 596 N50: 16807
# GCF_022213265.1 removed. Contigs: 118 N50: 151133
# GCF_022288725.1 removed. Contamination: 9.06 Completeness: 98.95
# GCF_022347745.1 removed. Contigs: 638 N50: 20066
# GCF_022392825.1 removed. Contamination: 6.01 Completeness: 99.93
# GCF_022414535.1 removed. Contigs: 134 N50: 127370
# GCF_022414575.1 removed. Contigs: 128 N50: 107719
# GCF_022414595.1 removed. Contigs: 147 N50: 84552
# GCF_022414615.1 removed. Contigs: 164 N50: 164408
# GCF_022414635.1 removed. Contigs: 169 N50: 100013
# GCF_022614595.1 removed. Contigs: 225 N50: 27697
# GCF_022695985.1 removed. Contigs: 461 N50: 29485
# GCF_023072675.1 removed. Contigs: 720 N50: 18780
# GCF_023072755.1 removed. Contigs: 422 N50: 26659
# GCF_023155275.1 removed. Contigs: 117 N50: 120589
# GCF_023370675.1 removed. Contigs: 257 N50: 227024
# GCF_023502025.1 removed. Contigs: 107 N50: 189032
# GCF_023502165.1 removed. Contigs: 114 N50: 126951
# GCF_023516595.1 removed. Contigs: 271 N50: 152317
# GCF_023516615.1 removed. Contigs: 363 N50: 71020
# GCF_023534765.1 removed. Contigs: 102 N50: 194184
# GCF_023544705.1 removed. Contigs: 138 N50: 131274
# GCF_023554615.1 removed. Contigs: 484 N50: 228026
# GCF_023630175.1 removed. Contigs: 142 N50: 122618
# GCF_023630275.1 removed. Contigs: 278 N50: 206944
# GCF_023667545.1 removed. Contigs: 493 N50: 26602
# GCF_023669525.1 removed. Contamination: 60.736677115987455 Completeness: 82.44514106583073
# GCF_023701525.1 removed. Contigs: 138 N50: 266232
# GCF_023713605.1 removed. Contigs: 176 N50: 243441
# GCF_023717205.1 removed. Contigs: 105 N50: 145714
# GCF_023717255.1 removed. Contamination: 5.79 Completeness: 99.47
# GCF_023805375.1 removed. Contigs: 177 N50: 116947
# GCF_023887685.1 removed. Contigs: 137 N50: 163816
# GCF_023930305.1 removed. Contigs: 129 N50: 117347
# GCF_024105145.1 removed. Contigs: 341 N50: 97324
# GCF_024105195.1 removed. Contigs: 575 N50: 131685
# GCF_024105205.1 removed. Contigs: 323 N50: 108708
# GCF_024105315.1 removed. Contigs: 169 N50: 146186
# GCF_024105335.1 removed. Contigs: 467 N50: 152463
# GCF_024107415.1 removed. Contigs: 421 N50: 148232
# GCF_024107435.1 removed. Contigs: 322 N50: 156924
# GCF_024107455.1 removed. Contigs: 198 N50: 170996
# GCF_024107465.1 removed. Contigs: 297 N50: 177678
# GCF_024107495.1 removed. Contigs: 503 N50: 204393
# GCF_024107515.1 removed. Contigs: 128 N50: 251296
# GCF_024138375.1 removed. Contigs: 392 N50: 40528
# GCF_024223055.1 removed. Contamination: 7.01 Completeness: 98.93
# GCF_024380135.1 removed. Contigs: 148 N50: 117468
# GCF_024435335.1 removed. Contigs: 181 N50: 91403
# GCF_024435355.1 removed. Contigs: 119 N50: 323159
# GCF_024436055.1 removed. Contamination: 6.84 Completeness: 100.0
# GCF_024448155.1 removed. Contigs: 378 N50: 39005
# GCF_024448165.1 removed. Contigs: 443 N50: 38974
# GCF_024448175.1 removed. Contigs: 354 N50: 34753
# GCF_024505145.1 removed. Contigs: 298 N50: 183891
# GCF_024505305.1 removed. Contigs: 107 N50: 305657
# GCF_024519315.1 removed. Contigs: 306 N50: 119153
# GCF_024519335.1 removed. Contigs: 110 N50: 173799
# GCF_024519455.1 removed. Contigs: 130 N50: 295667
# GCF_024539675.1 removed. Contigs: 949 N50: 44277
# GCF_024586905.1 removed. Contigs: 126 N50: 137629
# GCF_024721315.2 removed. Contigs: 408 N50: 45434
# GCF_024721345.1 removed. Contigs: 308 N50: 57957
# GCF_025153975.1 removed. Contigs: 113 N50: 158519
# GCF_025290915.1 removed. Contigs: 560 N50: 21691
# GCF_025399755.1 removed. Contigs: 585 N50: 27723
# GCF_025399765.1 removed. Contigs: 321 N50: 215380
# GCF_025399775.1 removed. Contigs: 320 N50: 69118
# GCF_025399795.1 removed. Contigs: 244 N50: 147426
# GCF_025568765.1 removed. Contigs: 156 N50: 214672
# GCF_025656915.1 removed. Contigs: 420 N50: 31411
# GCF_025716995.1 removed. Contigs: 619 N50: 22387
# GCF_025964845.1 removed. Contigs: 655 N50: 17082
# GCF_026008495.1 removed. Contigs: 228 N50: 163876
# GCF_026126445.1 removed. Contigs: 103 N50: 229202
# GCF_026168105.1 removed. Contigs: 159 N50: 151047
# GCF_026183975.1 removed. Contigs: 122 N50: 273762
# GCF_026184015.1 removed. Contigs: 109 N50: 165478
# GCF_026191925.1 removed. Contigs: 910 N50: 15672
# GCF_026242095.1 removed. Contigs: 107 N50: 260136
# GCF_026262575.1 removed. Contigs: 141 N50: 170825
# GCF_026274175.1 removed. Contigs: 342 N50: 37912
# GCF_026341425.1 removed. Contigs: 102 N50: 163682
# GCF_026420845.1 removed. Contigs: 105 N50: 186895
# GCF_026627185.1 removed. Contigs: 160 N50: 128302
# GCF_026627225.1 removed. Contigs: 274 N50: 49007
# GCF_026627245.1 removed. Contigs: 186 N50: 79368
# GCF_026627445.1 removed. Contigs: 176 N50: 150361
# GCF_026627485.1 removed. Contigs: 448 N50: 61903
# GCF_026627505.1 removed. Contigs: 380 N50: 79555
# GCF_026800165.1 removed. Contigs: 1345 N50: 55179
# GCF_026965885.1 removed. Contigs: 151 N50: 88305
# GCF_027157945.1 removed. Contigs: 303 N50: 64321
# GCF_027158125.1 removed. Contigs: 306 N50: 89003
# GCF_027158205.1 removed. Contigs: 146 N50: 156184
# GCF_027270795.1 removed. Contigs: 1048 N50: 19949
# GCF_027270915.1 removed. Contigs: 684 N50: 30252
# GCF_027270975.1 removed. Contigs: 964 N50: 14104
# GCF_027533845.1 removed. Contigs: 139 N50: 304118
# GCF_027570385.1 removed. Contigs: 241 N50: 109216
# GCF_027920075.1 removed. Contigs: 114 N50: 288023
# GCF_027947535.2 removed. Contamination: 5.307017543859649 Completeness: 99.47368421052632
# GCF_027947545.2 removed. Contigs: 112 N50: 180908
# GCF_028369295.1 removed. Contigs: 200 N50: 146433
# GCF_028401405.1 removed. Contigs: 256 N50: 148220
# GCF_028657195.3 removed. Contigs: 125 N50: 158355
# GCF_028863365.1 removed. Contigs: 137 N50: 339391
# GCF_029223525.1 removed. Contamination: 7.280701754385965 Completeness: 100.0
# GCF_029269095.1 removed. Contigs: 1671 N50: 12630
# GCF_029269835.1 removed. Contigs: 111 N50: 345819
# GCF_029813775.1 removed. Contigs: 164 N50: 147138
# GCF_029813835.1 removed. Contigs: 283 N50: 73719
# GCF_029846675.1 removed. Contigs: 116 N50: 146088
# GCF_029846775.1 removed. Contigs: 146 N50: 127268
# GCF_029892105.1 removed. Contigs: 138 N50: 200501
# GCF_029892145.1 removed. Contigs: 110 N50: 169698
# GCF_029894335.1 removed. Contigs: 118 N50: 135651
# GCF_029910965.1 removed. Contigs: 354 N50: 56750
# GCF_029946625.1 removed. Contigs: 586 N50: 25306
# GCF_029953285.1 removed. Contigs: 114 N50: 152462
# GCF_029967595.1 removed. Contigs: 264 N50: 58042
# GCF_029967605.1 removed. Contigs: 384 N50: 36481
# GCF_029968015.1 removed. Contigs: 113 N50: 164732
# GCF_030010495.1 removed. Contigs: 605 N50: 30402
# GCF_030010595.1 removed. Contigs: 276 N50: 67870
# GCF_030010605.1 removed. Contigs: 135 N50: 246320
# GCF_030010625.1 removed. Contigs: 129 N50: 149073
# GCF_030010655.1 removed. Contigs: 212 N50: 99634
# GCF_030010675.1 removed. Contigs: 791 N50: 19547
# GCF_030056615.1 removed. Contigs: 135 N50: 116958
# GCF_030063135.1 removed. Contigs: 140 N50: 129914
# GCF_030063325.1 removed. Contigs: 192 N50: 117472
# GCF_030063355.1 removed. Contigs: 237 N50: 81534
# GCF_030063415.1 removed. Contigs: 128 N50: 165176
# GCF_030122705.1 removed. Contamination: 5.2631578947368425 Completeness: 100.0
# GCF_030159695.1 removed. Contigs: 114 N50: 584103
# GCF_030238025.1 removed. Contigs: 166 N50: 108182
# GCF_030262575.1 removed. Contigs: 218 N50: 165811
# GCF_030268605.1 removed. Contigs: 197 N50: 244339
# GCF_030268625.1 removed. Contigs: 179 N50: 321264
# GCF_030268665.1 removed. Contigs: 340 N50: 165723
# GCF_030268805.1 removed. Contigs: 102 N50: 321888
# GCF_030268825.1 removed. Contigs: 221 N50: 138939
# GCF_030268885.1 removed. Contigs: 169 N50: 221631
# GCF_030270785.1 removed. Contigs: 187 N50: 189630
# GCF_900090095.1 removed. Contigs: 106 N50: 261762
# GCF_900091315.1 removed. Contigs: 243 N50: 70678
# GCF_900091485.1 removed. Contigs: 193 N50: 55778
# GCF_900091715.1 removed. Contigs: 239 N50: 56194
# GCF_900091725.1 removed. Contigs: 102 N50: 266092
# GCF_900091745.1 removed. Contigs: 118 N50: 133137
# GCF_900091755.1 removed. Contigs: 377 N50: 32343
# GCF_900091765.1 removed. Contigs: 301 N50: 38665
# GCF_900091785.1 removed. Contigs: 352 N50: 35237
# GCF_900091815.1 removed. Contigs: 652 N50: 18519
# GCF_900091825.1 removed. Contigs: 1185 N50: 7383
# GCF_900091835.1 removed. Contigs: 190 N50: 80767
# GCF_900091845.1 removed. Contigs: 400 N50: 38736
# GCF_900091855.1 removed. Contigs: 670 N50: 21543
# GCF_900091865.1 removed. Contigs: 253 N50: 52422
# GCF_900091875.1 removed. Contigs: 336 N50: 35127
# GCF_900091885.1 removed. Contigs: 157 N50: 88536
# GCF_900091905.1 removed. Contigs: 1456 N50: 8512
# GCF_900091955.1 removed. Contigs: 244 N50: 84953
# GCF_900091975.1 removed. Contigs: 242 N50: 72318
# GCF_900091985.1 removed. Contigs: 420 N50: 35698
# GCF_900091995.1 removed. Contigs: 1302 N50: 9389
# GCF_900092005.1 removed. Contigs: 176 N50: 91291
# GCF_900092015.1 removed. Contamination: 5.79 Completeness: 98.82
# GCF_900095575.1 removed. Contigs: 111 N50: 129868
# GCF_900110255.1 removed. Contigs: 112 N50: 183757
# GCF_900110755.1 removed. Contigs: 122 N50: 143556
# GCF_900114955.1 removed. Contigs: 106 N50: 302548
# GCF_900119365.1 removed. Contigs: 103 N50: 269459
# GCF_900171555.1 removed. Contigs: 334 N50: 48334
# GCF_900290235.1 removed. Contigs: 192 N50: 142982
# GCF_902506575.1 removed. Contigs: 159 N50: 7159421
# GCF_907177275.1 removed. Contigs: 135 N50: 178610
# GCF_913919575.1 removed. Contigs: 211 N50: 78904
# GCF_940670765.1 removed. Contigs: 144 N50: 235910
# GCF_945929885.1 removed. Contigs: 126 N50: 100724
# NBC_00217 removed. Contamination: 15.879828326180258 Completeness: 100.0
# NBC_00359 removed. Contamination: 5.181347150259067 Completeness: 100.0
# NBC_00845 removed. Contamination: 5.175438596491229 Completeness: 100.0
# NBC_00887 removed. Contamination: 23.6061684460261 Completeness: 100.0
# NBC_00899 removed. Contamination: 28.157894736842103 Completeness: 99.47368421052632
# NBC_01320 removed. Contamination: 5.160142348754448 Completeness: 100.0
# NBC_01484 removed. Contamination: 6.476683937823834 Completeness: 100.0
# NBC_01499 removed. Contamination: 5.027978496023608 Completeness: 99.74937343358395
# NBC_01510 removed. Contamination: 5.872193436960276 Completeness: 100.0
# NBC_01555 removed. Contamination: 5.175438596491229 Completeness: 100.0

# %%
df_stats.quality.value_counts()
# Out:
# quality
# HQ    1347
# LQ    1264
# MQ    1229
# Name: count, dtype: int64

# %% [markdown]
# # 4. Streptomyces genus medium quality project
#
# By following the above assessement, different quality filters were defined to select medium to high quality genomes for the next BGCFlow project called `mq_strepto`
#
# Low quality
# 1. CheckM contamination > 5 %
# 2. CheckM completeness < 90 %
# 3. Number of contigs > 100
# 4. N50 < 100 kb
#
# Medium quality
# 1. NCBI assembly level = Cotig, Scaffold
# 2. CheckM contamination <= 5 %
# 3. CheckM completeness <= 90 %
# 4. Number of contigs <= 100
# 5. N50 >= 100 kb
#
# High quality
# 1. NCBI assembly level = Complete genome, Chromosome
# 2. CheckM contamination <= 5 %
# 3. CheckM completeness <= 90 %
# 4. Number of contigs <= 100
# 5. N50 >= 100 kb

# %% [markdown]
# ### Setup the config project using BGCFlow wrapper
#
# Follow the guide to set up a project called "mq_strepto" with samples tables and project config with the following rules
#
# ```
# cd bgcflow_dir
# bgcflow init --project mq_strepto
# cp .examples/_genome_project_example/prokka-db.csv config/mq_strepto/
# ```

# %% [markdown]
# ## Update project_config
#
# Update the file `config/qc_strepto_ncbi/project_config.yaml` to allow seqfu rule on.
#
# Note that the latest release 214 of GTDB was used here with version 2.3.0 updated in the `workflow/envs/gtdbtk.yaml` file.
#
# ```
# name: mq_strepto
# pep_version: 2.1.0
# description: 'Project to of 2371 genomes of medium to high quality genomes of Streptomyces genus.'
# sample_table: samples.csv
# prokka-db: 'prokka-db.csv'
# rules:
#   seqfu: true
#   mash: true
#   prokka: true
#
# #### CUSTOM RULE CONFIGURATION ####
# rule_p  install_gtdbtk:
#     release: "214"
#     release_version: "214"
# ```

# %%
### Extract Streptomyces genus and MQ, HQ genomes

# %%
df_streptomyces = df_stats[df_stats.genus == "Streptomyces"]
df_strepto_mq = df_streptomyces[df_streptomyces.quality.isin(["HQ", "MQ"])]
df_strepto_mq.quality.value_counts()
# Out:
# quality
# HQ    1196
# MQ    1175
# Name: count, dtype: int64

# %%
df_samples_mq_ncbi = df_samples_strepto_ncbi_all.loc[df_strepto_mq[df_strepto_mq.source == "NCBI"].index,:] 
df_samples_mq_nbc = df_samples_NBC_902.loc[df_strepto_mq[df_strepto_mq.source == "NBC"].index,:] 
df_samples_mq_strepo = pd.concat([df_samples_mq_ncbi, df_samples_mq_nbc])
df_samples_mq_strepo
# Out:
#                  source organism genus species     strain  \
# genome_id
# GCF_000009765.2    ncbi      NaN   NaN     NaN        NaN
# GCF_000010605.1    ncbi      NaN   NaN     NaN        NaN
# GCF_000091305.1    ncbi      NaN   NaN     NaN        NaN
# GCF_000092385.1    ncbi      NaN   NaN     NaN        NaN
# GCF_000147815.2    ncbi      NaN   NaN     NaN        NaN
# ...                 ...      ...   ...     ...        ...
# NBC_01798        custom      NaN   NaN     NaN  NBC_01798
# NBC_01799        custom      NaN   NaN     NaN  NBC_01799
# NBC_01800        custom      NaN   NaN     NaN  NBC_01800
# NBC_01803        custom      NaN   NaN     NaN  NBC_01803
# NBC_01808        custom      NaN   NaN     NaN  NBC_01808
#
#                 closest_placement_reference
# genome_id
# GCF_000009765.2                         NaN
# GCF_000010605.1                         NaN
# GCF_000091305.1                         NaN
# GCF_000092385.1                         NaN
# GCF_000147815.2                         NaN
# ...                                     ...
# NBC_01798                               NaN
# NBC_01799                               NaN
# NBC_01800                               NaN
# NBC_01803                               NaN
# NBC_01808                               NaN
#
# [2371 rows x 6 columns]

# %%
df_strepto_mq.species.value_counts()[:40]
# Out:
# species
# sp.                   415
# albidoflavus          109
# anulatus               58
# olivaceus              46
# bacillaris             33
# canus                  29
# sp003846175            26
# californicus           24
# anthocyanicus          24
# papulosus              24
# rochei                 21
# mirabilis              21
# parvus                 20
# cellulosae             18
# clavuligerus           18
# microflavus            18
# virginiae_A            18
# libani                 15
# scabiei                15
# phaeochromogenes       15
# cyaneofuscatus         14
# silvae                 14
# griseoincarnatus       14
# griseoaurantiacus      13
# platensis              13
# fimicarius             12
# chartreusis            12
# griseus                12
# goshikiensis           12
# globisporus            12
# sp900116325            11
# sp001905735            11
# rubiginosohelvolus     11
# fungicidicus           11
# longwoodensis          11
# sp900105515            10
# sp000772045            10
# diastaticus            10
# halstedii              10
# sp000177195             9
# Name: count, dtype: int64

# %%
import plotly.express as px

df = df_strepto_mq.copy()

# filter top 20 species
top_species_names = species_counts[:20].index
df_top_species = df[df['species'].isin(top_species_names)]

# create a new column combining 'source' and 'quality'
df_top_species['source_quality'] = df_top_species['source'] + '-' + df_top_species['quality']

# compute total counts for each species
species_total_counts = df_top_species['species'].value_counts()

# sort species by total counts
df_top_species['species'] = pd.Categorical(df_top_species['species'], categories=species_total_counts.index, ordered=True)

fig = px.histogram(df_top_species, x="species", color="source_quality",
                   barmode="stack",
                   title="Distribution of Top 20 Species by Source and Quality",
                   labels={'species':'Species', 'source_quality':'Source and Quality', 'count':'Count'})

fig.update_layout(height=600, showlegend=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 6
#       3 df = df_strepto_mq.copy()
#       5 # filter top 20 species
# ----> 6 top_species_names = species_counts[:20].index
#       7 df_top_species = df[df['species'].isin(top_species_names)]
#       9 # create a new column combining 'source' and 'quality'
#
# NameError: name 'species_counts' is not defined

# %%
# Write samples.csv table to config directory of qc_strepto_ncbi project
project_name_4 = "mq_strepto"
config_dir_4 = bgcflow_dir / f"config/{project_name_4}"

samples_mq_strepto_table = config_dir_4 / "samples.csv"
# df_samples_mq_strepo.to_csv(samples_table)

# %%
processed_dir_4 = bgcflow_dir / "data" / "processed" / project_name_4

# %%
# df_stats.to_csv(processed_dir_1 / "tables" / "df_filters.csv")
# df_stats.to_csv(processed_dir_2 / "tables" / "df_filters.csv")
# df_strepto_mq.to_csv(processed_dir_4 / "tables" / "df_filters.csv")

# %% [markdown]
# # 5. Streptomyces phylogroup projects
#
# We used the MASH based clustering to define consistent phylogroups. Here a separate project is created for each of the phylgroups for detailed analysis.

# %% [markdown]
# ### Setup the config project using BGCFlow wrapper
#
# Follow the guide to set up a project called "mq_strepto" with samples tables and project config with the following rules
#
# ```
# cd bgcflow_dir
# bgcflow init --project P1
# cp .examples/_genome_project_example/prokka-db.csv config/P1/
# ```

# %% [markdown]
# ## Update project_config
#
# Update the file `config/P1/project_config.yaml` to allow seqfu rule on.
#
# ```
# name: P1
# pep_version: 2.1.0
# description: 'Project to of individual phylogroups defined using MASH.'
# sample_table: samples.csv
# prokka-db: 'prokka-db.csv'
# rules:
#   seqfu: true
#   bigscape: true
#
# #### CUSTOM RULE CONFIGURATION ####
# rule_p  install_gtdbtk:
#     release: "214"
#     release_version: "214"
# ```

# %%
samples_mq = bgcflow_dir / "config" / "mq_strepto" / "samples.csv"
df_samples_mq = pd.read_csv(samples_mq, index_col= 0)

# %%
df_mash_clusters = pd.read_csv("assets/tables/df_mash_clusters_main_reduced.csv", index_col=0)
cluster_list = sorted(df_mash_clusters.Cluster.unique())
for cluster in cluster_list:
    phylogroup = "P" + str(cluster)
    genome_list = df_mash_clusters[df_mash_clusters.Cluster == cluster].index.tolist()
    df_samples_phylogroup = df_samples_mq.loc[genome_list, :]
    samples_phylo_table = bgcflow_dir / "config" / phylogroup / "samples.csv"
    df_samples_phylogroup.to_csv(samples_phylo_table)

# %%
# Write samples.csv table to config directory of qc_strepto_ncbi project
project_name_4 = "mq_strepto"
config_dir_4 = bgcflow_dir / f"config/{project_name_4}"

samples_mq_strepto_table = config_dir_4 / "samples.csv"
# df_samples_mq_strepo.to_csv(samples_table)
